# %% [markdown]
# ### Import the necessary packages and load the data

# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import GroupShuffleSplit
from hmmlearn import hmm
import sklearn
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
# !pip install hmmlearn
# Out:
# Collecting hmmlearn
#   Downloading hmmlearn-0.3.0-cp39-cp39-win_amd64.whl (123 kB)
# Requirement already satisfied: numpy>=1.10 in c:\users\admin\anaconda3\lib\site-packages (from hmmlearn) (1.22.4)
# Requirement already satisfied: scikit-learn!=0.22.0,>=0.16 in c:\users\admin\anaconda3\lib\site-packages (from hmmlearn) (1.0.2)
# Requirement already satisfied: scipy>=0.19 in c:\users\admin\anaconda3\lib\site-packages (from hmmlearn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (1.1.0)
# Installing collected packages: hmmlearn
# Successfully installed hmmlearn-0.3.0

# %%
data = pd.read_csv('ner_dataset.csv', encoding = "latin1")
data.head()
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1          NaN             of   IN   O
# 2          NaN  demonstrators  NNS   O
# 3          NaN           have  VBP   O
# 4          NaN        marched  VBN   O

# %% [markdown]
# ### Data Preprocessing and Data Cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Sentence #  47959 non-null    object
#  1   Word        1048575 non-null  object
#  2   POS         1048575 non-null  object
#  3   Tag         1048575 non-null  object
# dtypes: object(4)
# memory usage: 32.0+ MB

# %%
data.nunique()
# Out:
# Sentence #    47959
# Word          35178
# POS              42
# Tag              17
# dtype: int64

# %%
data.rename(columns={'Sentence #':'Sentence'}, inplace=True)

# %%
data = data.fillna(method = 'ffill')

# %%
data.isnull().sum()
# Out:
# Sentence    0
# Word        0
# POS         0
# Tag         0
# dtype: int64

# %%
print(data.head(10))
print(data.tail(10))
# Out:
#       Sentence           Word  POS    Tag
# 0  Sentence: 1      Thousands  NNS      O
# 1  Sentence: 1             of   IN      O
# 2  Sentence: 1  demonstrators  NNS      O
# 3  Sentence: 1           have  VBP      O
# 4  Sentence: 1        marched  VBN      O
# 5  Sentence: 1        through   IN      O
# 6  Sentence: 1         London  NNP  B-geo
# 7  Sentence: 1             to   TO      O
# 8  Sentence: 1        protest   VB      O
# 9  Sentence: 1            the   DT      O
#                 Sentence       Word  POS    Tag
# 1048565  Sentence: 47958     impact   NN      O
# 1048566  Sentence: 47958          .    .      O
# 1048567  Sentence: 47959     Indian   JJ  B-gpe
# 1048568  Sentence: 47959     forces  NNS      O
# 1048569  Sentence: 47959       said  VBD      O
# 1048570  Sentence: 47959       they  PRP      O
# 1048571  Sentence: 47959  responded  VBD      O
# 1048572  Sentence: 47959         to   TO      O
# 1048573  Sentence: 47959        the   DT      O
# 1048574  Sentence: 47959     attack   NN      O

# %%
' '.join(data[data['Sentence'] == 'Sentence: 1']['Word'].values)
# Out:
# 'Thousands of demonstrators have marched through London to protest the war in Iraq and demand the withdrawal of British troops from that country .'

# %%
' '.join(data[data['Sentence'] == 'Sentence: 2']['Word'].values)
# Out:
# 'Families of soldiers killed in the conflict joined the protesters who carried banners with such slogans as " Bush Number One Terrorist " and " Stop the Bombings . "'

# %%
' '.join(data[data['Sentence'] == 'Sentence: 47959']['Word'].values)
# Out:
# 'Indian forces said they responded to the attack'

# %%
data['Tag'].value_counts()
# Out:
# O        887908
# B-geo     37644
# B-tim     20333
# B-org     20143
# I-per     17251
# B-per     16990
# I-org     16784
# B-gpe     15870
# I-geo      7414
# I-tim      6528
# B-art       402
# B-eve       308
# I-art       297
# I-eve       253
# B-nat       201
# I-gpe       198
# I-nat        51
# Name: Tag, dtype: int64

# %%
tags = list(set(data['Tag'].values))
words = list(set(data['Word'].values))
print('Number of unique words in the dataset:', len(words))
print('Number of unique tags in the dataset:', len(tags))
# Out:
# Number of unique words in the dataset: 35178
# Number of unique tags in the dataset: 17

# %% [markdown]
# ### Data Preparation - Split the data into train and test set

# %% [markdown]
# We use **GroupShuffleSplit** to spilt the data into train and test set as using **train_test_split** will make some parts of the sentence go to train set and others to test set

# %%
data.columns
# Out:
# Index(['Sentence', 'Word', 'POS', 'Tag'], dtype='object')

# %%
y = data['Tag']
x = data.drop(columns='Tag')

# %%
split_gs = GroupShuffleSplit(n_splits=3, test_size=0.3, random_state=42)
# n_splitsint, default=5 : Number of re-shuffling & splitting iterations.

# %%
x_train, x_test = next(split_gs.split(x, y, groups=x['Sentence']))

# %%
x.shape
# Out:
# (1048575, 3)

# %%
x_train.shape, x_test.shape
# Out:
# ((734523,), (314052,))

# %%
train_data = data.iloc[x_train]
test_data = data.iloc[x_test]

# %%
train_data.shape, test_data.shape
# Out:
# ((734523, 4), (314052, 4))

# %%
train_data.head()
# Out:
#        Sentence      Word  POS Tag
# 24  Sentence: 2  Families  NNS   O
# 25  Sentence: 2        of   IN   O
# 26  Sentence: 2  soldiers  NNS   O
# 27  Sentence: 2    killed  VBN   O
# 28  Sentence: 2        in   IN   O

# %%
data_update = train_data.sample(frac=0.1, replace=False, random_state=42).reset_index(drop=True)

# %%
data_update.shape
# Out:
# (73452, 4)

# %%
data_update.head()
# Out:
#           Sentence    Word  POS Tag
# 0  Sentence: 23582     the   DT   O
# 1  Sentence: 12377      of   IN   O
# 2  Sentence: 26652       .    .   O
# 3   Sentence: 9035     the   DT   O
# 4  Sentence: 16245  killed  VBN   O

# %%
data_update.Word = "UNKNOWN"

# %%
train_data['Word'].unique()
# Out:
# array(['Families', 'of', 'soldiers', ..., 'Soe', '3700', 'Bermel'],
#       dtype=object)

# %%
train_data.update(data_update)
# Out:
# C:\Temp\ipykernel_12204\1501397837.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.update(data_update)

# %%
train_data['Word'].unique()
# Out:
# array(['UNKNOWN', 'the', 'illness', ..., 'Soe', '3700', 'Bermel'],
#       dtype=object)

# %%
display(train_data.head().reset_index(drop=True))
display(train_data.tail().reset_index(drop=True))
# Out:
#           Sentence     Word  POS Tag
# 0  Sentence: 31683  UNKNOWN  NNP   O
# 1   Sentence: 8392  UNKNOWN   DT   O
# 2  Sentence: 28070  UNKNOWN  NNS   O
# 3  Sentence: 40293  UNKNOWN   DT   O
# 4  Sentence: 44552  UNKNOWN   IN   O
#           Sentence       Word  POS Tag
# 0  Sentence: 47959       they  PRP   O
# 1  Sentence: 47959  responded  VBD   O
# 2  Sentence: 47959         to   TO   O
# 3  Sentence: 47959        the   DT   O
# 4  Sentence: 47959     attack   NN   O

# %%
print(words[:10])
# Out:
# ['censored', 'Dragmulla', 'foster', 'analysts', 'tilt', 'Dick', 'Sirnak', 'Tanith', 'Dhabi', 'dominance']

# %%
word2id = {w:i for i,w in enumerate(words)}
tag2id = {t:i for i,t in enumerate(tags)}
id2tag = {i:t for i,t in enumerate(tags)}

# %%
print(word2id)
# Out:
# {'censored': 0, 'Dragmulla': 1, 'foster': 2, 'analysts': 3, 'tilt': 4, 'Dick': 5, 'Sirnak': 6, 'Tanith': 7, 'Dhabi': 8, 'dominance': 9, 'recommended': 10, 'Raffaele': 11, 'Majlis-e-Amal': 12, 'Warlords': 13, 'repressing': 14, 'budgets': 15, 'Krzyzewski': 16, 'clash': 17, 'discovering': 18, 'HELP': 19, 'event': 20, 'reversed': 21, 'stole': 22, 'supervise': 23, 'loses': 24, 'pork': 25, 'simplification': 26, 'Friedan': 27, 'methamphetamine': 28, 'crushed': 29, 'Marlins': 30, 'Asked': 31, 'grata': 32, 'Melli': 33, '-': 34, 'Accordance': 35, 'al-Talhi': 36, 'socialist': 37, 'Rahman': 38, 'Sibal': 39, 'catching': 40, 'avoid': 41, 'steam': 42, 'de-orbiting': 43, 'subcommittee': 44, 'sponsorship': 45, 'Port': 46, 'protect': 47, 'salivated': 48, 'Brett': 49, 'reshuffled': 50, 'Barbara': 51, 'Halliburton': 52, '46-member': 53, 'Barbour': 54, 'ploy': 55, 'Minster': 56, 'kidnappings': 57, 'Jalani': 58, 'betting': 59, 'gathering': 60, 'bailout': 61, 'countering': 62, 'spur': 63, 'reflects': 64, '1.24': 65, 'systems': 66, 'Majority': 67, 'Store': 68, 'standing': 69, 'anti-Syria': 70, 'greenhouse': 71, 'cocoa': 72, 'Agnes': 73, 'culled': 74, 'suppressed': 75, 'Alfredo': 76, 'incumbent': 77, 'automobile': 78, '7.5': 79, 'Medan': 80, 'Hundreds': 81, 'vomit': 82, 'Sales': 83, 'Jhy-wey': 84, 'Hamas-ruled': 85, 'AU-sponsored': 86, 'settle': 87, 'demolished': 88, 'then-President': 89, 'recessed': 90, '8.2': 91, 'empowered': 92, 'Makepeace': 93, '12-month': 94, 'Singye': 95, 'separatism': 96, 'rugby': 97, 'small-and': 98, 'dated': 99, 'Al-Bahlul': 100, 'reimposed': 101, 'suffocating': 102, 'inconvenient': 103, 'declares': 104, 'briefly': 105, 'earthquakes': 106, 'HOPE': 107, 'seafood': 108, 'observances': 109, 'very': 110, 'Petrocaribe': 111, 'journeyed': 112, 'whichever': 113, 'risk': 114, 'winner': 115, 'twins': 116, 'Polynesian': 117, 'Querrey': 118, 'groan': 119, 'Pro-Western': 120, '5,50,000': 121, 'Anabel': 122, 'Catholic': 123, 'refrained': 124, 'approving': 125, 'lash': 126, 'Piano': 127, 'Litani': 128, 'Infrared': 129, 'ventilation': 130, 'Paulo': 131, 'Yafei': 132, '14.75': 133, '500-meter': 134, 'Borena': 135, 'something': 136, 'menstrual': 137, 'Auschwitz': 138, 'Battalion': 139, 'Noordin': 140, 'Wagner': 141, 'Wajama': 142, 'dilemma': 143, 'enthusiasm': 144, 'storage': 145, 'Hawaii': 146, 'senators': 147, 'Deh': 148, 'bright': 149, '25,000': 150, 'Oil': 151, 'Visiting': 152, 'intestinal': 153, 'Horn': 154, 'Valle': 155, 'middleman': 156, 'gambled': 157, 'high-income': 158, '17-month': 159, 'transport': 160, 'Tarija': 161, 'Minas': 162, '150-member': 163, 'depend': 164, 'Vienna-based': 165, 'projecting': 166, 'Reid': 167, 'employee': 168, 'reached': 169, 'Blanco': 170, '2,20,000': 171, 'Tom': 172, 'tombstone': 173, 'strife': 174, 'diplomacy': 175, '17-member': 176, 'shines': 177, 'effort': 178, 'already': 179, 'enforced': 180, 'unregulated': 181, 'Center-left': 182, 'gorgeous': 183, 'seamen': 184, 'Aside': 185, 'sauntering': 186, 'resemble': 187, 'replacement': 188, 'demonizing': 189, '1,70,000': 190, 'splash': 191, 'ONCE': 192, 'jailings': 193, 'delayed': 194, 'tube': 195, 'Pakistani-controlled': 196, 'Boucher': 197, 'achievement': 198, 'One': 199, 'Carolina': 200, 'Peshawar': 201, 'remember': 202, 'Landlocked': 203, 'royalties': 204, 'cave-in': 205, 'Nations-coordinated': 206, 'Kane': 207, 'Pavarotti': 208, 'tip': 209, 'Adelaide': 210, 'Newcastle': 211, 'learns': 212, 'Edison': 213, 'Peugeot-Citroen': 214, 'Tomorrow': 215, 'FM': 216, 'Taleban-led': 217, 'rate': 218, 'Tunceli': 219, 'downhills': 220, 'twisted': 221, 'firearm': 222, 'under': 223, 'defeated': 224, 'al-Qaida': 225, 'Hajim': 226, 'installs': 227, 'supported': 228, 'anti-Tutsi': 229, 'grandson': 230, 'advances': 231, 'liberalize': 232, 'vessels': 233, 'meddling': 234, 'referring': 235, 'Afghan-international': 236, 'Zionism': 237, 'Eurasian': 238, 'wall': 239, 'Letten': 240, 'Banadir': 241, 'Biden': 242, 'Albert': 243, 'Tito': 244, 'bomb-grade': 245, 'cost-cutting': 246, 'Op ...

# %%
print(tag2id)
# Out:
# {'B-geo': 0, 'O': 1, 'I-geo': 2, 'I-tim': 3, 'I-nat': 4, 'I-per': 5, 'B-gpe': 6, 'I-gpe': 7, 'B-org': 8, 'I-eve': 9, 'B-eve': 10, 'I-art': 11, 'B-tim': 12, 'B-nat': 13, 'B-per': 14, 'I-org': 15, 'B-art': 16}

# %%
print(id2tag)
# Out:
# {0: 'B-geo', 1: 'O', 2: 'I-geo', 3: 'I-tim', 4: 'I-nat', 5: 'I-per', 6: 'B-gpe', 7: 'I-gpe', 8: 'B-org', 9: 'I-eve', 10: 'B-eve', 11: 'I-art', 12: 'B-tim', 13: 'B-nat', 14: 'B-per', 15: 'I-org', 16: 'B-art'}

# %% [markdown]
# ### Hidden Markov Models

# %%
count_tags = dict(train_data['Tag'].value_counts())
print(count_tags)
# Out:
# {'O': 621981, 'B-geo': 26568, 'B-tim': 14380, 'B-org': 14062, 'I-per': 11998, 'B-per': 11835, 'I-org': 11799, 'B-gpe': 10912, 'I-geo': 5246, 'I-tim': 4692, 'B-art': 255, 'B-eve': 192, 'I-art': 174, 'I-eve': 149, 'B-nat': 130, 'I-gpe': 123, 'I-nat': 27}

# %%
train_data.head()
# Out:
#            Sentence     Word  POS Tag
# 24  Sentence: 31683  UNKNOWN  NNP   O
# 25   Sentence: 8392  UNKNOWN   DT   O
# 26  Sentence: 28070  UNKNOWN  NNS   O
# 27  Sentence: 40293  UNKNOWN   DT   O
# 28  Sentence: 44552  UNKNOWN   IN   O

# %%
grouped_data = train_data.groupby('Tag')
for group_name, group_data in grouped_data:
    print(f"Group: {group_name}")
    display(group_data)
# Out:
# Group: B-art
#                 Sentence        Word  POS    Tag
# 13288    Sentence: 10857     UNKNOWN   IN  B-art
# 14210    Sentence: 21780     UNKNOWN  NNP  B-art
# 15551    Sentence: 46145     UNKNOWN  NNP  B-art
# 20690     Sentence: 8926     UNKNOWN   NN  B-art
# 25429    Sentence: 26264     UNKNOWN  NNP  B-art
# ...                  ...         ...  ...    ...
# 1027190  Sentence: 46974         Arc  NNP  B-art
# 1033280  Sentence: 47247      Google  NNP  B-art
# 1041052  Sentence: 47608         Zim  NNP  B-art
# 1041448  Sentence: 47627  al-Jazeera  NNP  B-art
# 1042095  Sentence: 47660        Camp  NNP  B-art
#
# [255 rows x 4 columns]
# Group: B-eve
#                 Sentence       Word  POS    Tag
# 10337    Sentence: 26807    UNKNOWN  NNP  B-eve
# 21751     Sentence: 9008    UNKNOWN  NNP  B-eve
# 26762     Sentence: 1962    UNKNOWN  NNP  B-eve
# 35414    Sentence: 32870    UNKNOWN  NNP  B-eve
# 36708     Sentence: 8482    UNKNOWN  NNS  B-eve
# ...                  ...        ...  ...    ...
# 1027168  Sentence: 46973  Armistice  NNP  B-eve
# 1027179  Sentence: 46974      World  NNP  B-eve
# 1041907  Sentence: 47649         II  NNP  B-eve
# 1041940  Sentence: 47651      World  NNP  B-eve
# 1042880  Sentence: 47696         II  NNP  B-eve
#
# [192 rows x 4 columns]
# Group: B-geo
#                 Sentence      Word  POS    Tag
# 30       Sentence: 18569   UNKNOWN  NNP  B-geo
# 38        Sentence: 8410   UNKNOWN   NN  B-geo
# 103      Sentence: 40919   UNKNOWN  NNP  B-geo
# 125      Sentence: 42300   UNKNOWN  NNP  B-geo
# 130      Sentence: 46773   UNKNOWN  NNP  B-geo
# ...                  ...       ...  ...    ...
# 1048181  Sentence: 47941  southern   JJ  B-geo
# 1048221  Sentence: 47943     Burma  NNP  B-geo
# 1048456  Sentence: 47953    Bermel  NNP  B-geo
# 1048459  Sentence: 47953   Paktika  NNP  B-geo
# 1048518  Sentence: 47955    Punjab  NNP  B-geo
#
# [26568 rows x 4 columns]
# Group: B-gpe
#                 Sentence       Word  POS    Tag
# 265      Sentence: 10972    UNKNOWN   JJ  B-gpe
# 598       Sentence: 1048    UNKNOWN   JJ  B-gpe
# 604      Sentence: 35255    UNKNOWN   JJ  B-gpe
# 893      Sentence: 42188    UNKNOWN   JJ  B-gpe
# 1003     Sentence: 45570    UNKNOWN  NNP  B-gpe
# ...                  ...        ...  ...    ...
# 1048465  Sentence: 47953     Afghan   JJ  B-gpe
# 1048501  Sentence: 47955     Indian   JJ  B-gpe
# 1048508  Sentence: 47955  Pakistani   JJ  B-gpe
# 1048521  Sentence: 47956     Indian   JJ  B-gpe
# 1048567  Sentence: 47959     Indian   JJ  B-gpe
#
# [10912 rows x 4 columns]
# Group: B-nat
#                 Sentence     Word  POS    Tag
# 4075     Sentence: 40041  UNKNOWN  NNP  B-nat
# 14665    Sentence: 11690  UNKNOWN  NNP  B-nat
# 16263    Sentence: 39034  UNKNOWN  NNP  B-nat
# 21853    Sentence: 32344  UNKNOWN  NNP  B-nat
# 30376    Sentence: 45126  UNKNOWN  NNP  B-nat
# ...                  ...      ...  ...    ...
# 986989   Sentence: 45125  Marburg  NNP  B-nat
# 987023   Sentence: 45126  Marburg  NNP  B-nat
# 997163   Sentence: 45597     2007  NNP  B-nat
# 1005549  Sentence: 45978     AIDS  NNP  B-nat
# 1041200  Sentence: 47615     H5N1  NNP  B-nat
#
# [130 rows x 4 columns]
# Group: B-org
#                 Sentence     Word  POS    Tag
# 45       Sentence: 38559  UNKNOWN  NNP  B-org
# 49       Sentence: 41902  UNKNOWN  NNP  B-org
# 88        Sentence: 1168  UNKNOWN  NNP  B-org
# 92       Sentence: 17780  UNKNOWN   JJ  B-org
# 129      Sentence: 27387  UNKNOWN  NNP  B-org
# ...                  ...      ...  ...    ...
# 1048289  Sentence: 47945    Thura  NNP  B-org
# 1048338  Sentence: 47947  General  NNP  B-org
# 1048376  Sentence: 47950    Joint  NNP  B-org
# 1048450  Sentence: 47953  Taleban  NNP  B-org
# 1048463  Sentence: 47953     NATO  NNP  B-org
#
# [14062 rows x 4 columns]
# Group: B-per
#                 Sentence      Word  POS    Tag
# 93       Sentence: 42643   UNKNOWN  NNP  B-per
# 108       Sentence: 4312   UNKNOWN  NNP  B-per
# 115      Sentence: 34476   UNKNOWN  NNP  B-per
# 222      Sentence: 30474   UNKNOWN  NNP  B-per
# 254      Sentence: 43718   UNKNOWN  NNP  B-per
# ...                  ...       ...  ...    ...
# 1048156  Sentence: 47940     David  NNP  B-per
# 1048191  Sentence: 47941  Richards  NNP  B-per
# 1048209  Sentence: 47942  Richards  NNP  B-per
# 1048229  Sentence: 47943  Minister  NNP  B-per
# 1048316  Sentence: 47946      Khin  NNP  B-per
#
# [11835 rows x 4 columns]
# Group: B-tim
#                 Sentence         Word  POS    Tag
# 43       Sentence: 22331      UNKNOWN  NNP  B-tim
# 112      Sentence: 24312      UNKNOWN  NNP  B-tim
# 256      Sentence: 17485      UNKNOWN   CD  B-tim
# 337      Sentence: 45719      UNKNOWN  NNP  B-tim
# 460      Sentence: 11893      UNKNOWN  NNP  B-tim
# ...                  ...          ...  ...    ...
# 1048226  Sentence: 47943        today   NN  B-tim
# 1048333  Sentence: 47947      October  NNP  B-tim
# 1048371  Sentence: 47949  Afghanistan  NNP  B-tim
# 1048381  Sentence: 47950       Monday  NNP  B-tim
# 1048529  Sentence: 47956     Saturday  NNP  B-tim
#
# [14380 rows x 4 columns]
# Group: I-art
#                 Sentence      Word  POS    Tag
# 2669     Sentence: 28696   UNKNOWN  NNP  I-art
# 12964    Sentence: 11286   UNKNOWN   IN  I-art
# 18643    Sentence: 33786   UNKNOWN  NNP  I-art
# 22885    Sentence: 40538   UNKNOWN  NNP  I-art
# 25277    Sentence: 30419   UNKNOWN  NNP  I-art
# ...                  ...       ...  ...    ...
# 1022277  Sentence: 46750       Day  NNP  I-art
# 1027191  Sentence: 46974        de  NNP  I-art
# 1027192  Sentence: 46974  Triomphe  NNP  I-art
# 1041053  Sentence: 47608      Asia  NNP  I-art
# 1042096  Sentence: 47660     David  NNP  I-art
#
# [174 rows x 4 columns]
# Group: I-eve
#                 Sentence     Word  POS    Tag
# 3150     Sentence: 39078  UNKNOWN  NNP  I-eve
# 10168    Sentence: 21776  UNKNOWN  NNP  I-eve
# 13227    Sentence: 11567  UNKNOWN  NNP  I-eve
# 29782    Sentence: 46749  UNKNOWN  NNP  I-eve
# 30344     Sentence: 5510  UNKNOWN  NNP  I-eve
# ...                  ...      ...  ...    ...
# 1027169  Sentence: 46973      Day  NNP  I-eve
# 1027180  Sentence: 46974      War  NNP  I-eve
# 1027181  Sentence: 46974        I  NNP  I-eve
# 1041941  Sentence: 47651      War  NNP  I-eve
# 1041942  Sentence: 47651       II  NNP  I-eve
#
# [149 rows x 4 columns]
# Group: I-geo
#                 Sentence         Word   POS    Tag
# 97        Sentence: 1362      UNKNOWN  NNPS  I-geo
# 905      Sentence: 11334      UNKNOWN   NNP  I-geo
# 1028     Sentence: 41070      UNKNOWN   NNP  I-geo
# 1210     Sentence: 43841      UNKNOWN   NNP  I-geo
# 1312     Sentence: 26515      UNKNOWN   NNP  I-geo
# ...                  ...          ...   ...    ...
# 1047162  Sentence: 47887        Rouge   NNP  I-geo
# 1047365  Sentence: 47898        India   NNP  I-geo
# 1047948  Sentence: 47926  Afghanistan   NNP  I-geo
# 1048073  Sentence: 47934  Afghanistan   NNP  I-geo
# 1048182  Sentence: 47941  Afghanistan   NNP  I-geo
#
# [5246 rows x 4 columns]
# Group: I-gpe
#                 Sentence      Word  POS    Tag
# 12277     Sentence: 3204   UNKNOWN  NNP  I-gpe
# 19856    Sentence: 20428   UNKNOWN  NNP  I-gpe
# 41358     Sentence: 3675   UNKNOWN   JJ  I-gpe
# 58292    Sentence: 23363   UNKNOWN   JJ  I-gpe
# 61769    Sentence: 43956   UNKNOWN   JJ  I-gpe
# ...                  ...       ...  ...    ...
# 1015200  Sentence: 46423     Serbs  NNS  I-gpe
# 1015213  Sentence: 46423      Serb   JJ  I-gpe
# 1038033  Sentence: 47463     Croat   JJ  I-gpe
# 1038535  Sentence: 47487      Serb   JJ  I-gpe
# 1046142  Sentence: 47843  American   JJ  I-gpe
#
# [123 rows x 4 columns]
# Group: I-nat
#                Sentence         Word  POS    Tag
# 47926   Sentence: 34647      UNKNOWN  NNP  I-nat
# 107418   Sentence: 4883      Katrina  NNP  I-nat
# 110107   Sentence: 5011      Katrina  NNP  I-nat
# 110169   Sentence: 5014      Katrina  NNP  I-nat
# 131770   Sentence: 6017      Katrina  NNP  I-nat
# 193933   Sentence: 8882          flu   NN  I-nat
# 226400  Sentence: 10362      disease   NN  I-nat
# 226407  Sentence: 10363          Two   CD  I-nat
# 226408  Sentence: 10363     diabetes  NNS  I-nat
# 250023  Sentence: 11438         Rita  NNP  I-nat
# 254521  Sentence: 11643      Katrina  NNP  I-nat
# 319625  Sentence: 14636      Katrina  NNP  I-nat
# 491333  Sentence: 22480      superba  NNP  I-nat
# 491346  Sentence: 22480  eleginoides  NNP  I-nat
# 585339  Sentence: 26766         suis  NNP  I-nat
# 748565  Sentence: 34217          Flu  NNP  I-nat
# 748586  Sentence: 34218          Flu  NNP  I-nat
# 750053  Sentence: 34287         Rita  NNP  I-nat
# 758149  Sentence: 34647         Rita  NNP  I-nat
# 841020  Sentence: 38444         Rita  NNP  I-nat
# 849568  Sentence: 38815         Rita  NNP  I-nat
# 896254  Sentence: 40932        Storm  NNP  I-nat
# 896255  Sentence: 40932         Rita  NNP  I-nat
# 900430  Sentence: 41116      Katrina  NNP  I-nat
# 926209  Sentence: 42309           TB  NNP  I-nat
# 954587  Sentence: 43632      Katrina  NNP  I-nat
# 997164  Sentence: 45597          WD5  NNP  I-nat
# Group: I-org
#                 Sentence          Word  POS    Tag
# 70       Sentence: 33896       UNKNOWN  NNP  I-org
# 74        Sentence: 6926       UNKNOWN    ,  I-org
# 100      Sentence: 32160       UNKNOWN  NNP  I-org
# 127      Sentence: 17085       UNKNOWN  NNP  I-org
# 238      Sentence: 28411       UNKNOWN  NNP  I-org
# ...                  ...           ...  ...    ...
# 1048340  Sentence: 47947           Win  NNP  I-org
# 1048377  Sentence: 47950  Coordination  NNP  I-org
# 1048378  Sentence: 47950           and   CC  I-org
# 1048379  Sentence: 47950    Monitoring  NNP  I-org
# 1048380  Sentence: 47950         Board  NNP  I-org
#
# [11799 rows x 4 columns]
# Group: I-per
#                 Sentence      Word  POS    Tag
# 106       Sentence: 2393   UNKNOWN  NNP  I-per
# 116      Sentence: 39633   UNKNOWN  NNP  I-per
# 124      Sentence: 15431   UNKNOWN  NNP  I-per
# 246      Sentence: 22829   UNKNOWN  NNP  I-per
# 343      Sentence: 30836   UNKNOWN  NNP  I-per
# ...                  ...       ...  ...    ...
# 1048135  Sentence: 47939    Karzai  NNP  I-per
# 1048157  Sentence: 47940  Richards  NNP  I-per
# 1048230  Sentence: 47943      Khin  NNP  I-per
# 1048231  Sentence: 47943     Nyunt  NNP  I-per
# 1048317  Sentence: 47946     Nyunt  NNP  I-per
#
# [11998 rows x 4 columns]
# Group: I-tim
#                 Sentence     Word POS    Tag
# 75        Sentence: 3864  UNKNOWN  CD  I-tim
# 522      Sentence: 27757  UNKNOWN  CD  I-tim
# 607       Sentence: 7878  UNKNOWN  NN  I-tim
# 769      Sentence: 27182  UNKNOWN  CC  I-tim
# 944      Sentence: 39400  UNKNOWN  CD  I-tim
# ...                  ...      ...  ..    ...
# 1046766  Sentence: 47869     1992  CD  I-tim
# 1046767  Sentence: 47869      and  CC  I-tim
# 1046768  Sentence: 47869     2000  CD  I-tim
# 1047132  Sentence: 47886       18  CD  I-tim
# 1048334  Sentence: 47947       19  CD  I-tim
#
# [4692 rows x 4 columns]
# Group: O
#                 Sentence       Word  POS Tag
# 24       Sentence: 31683    UNKNOWN  NNP   O
# 25        Sentence: 8392    UNKNOWN   DT   O
# 26       Sentence: 28070    UNKNOWN  NNS   O
# 27       Sentence: 40293    UNKNOWN   DT   O
# 28       Sentence: 44552    UNKNOWN   IN   O
# ...                  ...        ...  ...  ..
# 1048570  Sentence: 47959       they  PRP   O
# 1048571  Sentence: 47959  responded  VBD   O
# 1048572  Sentence: 47959         to   TO   O
# 1048573  Sentence: 47959        the   DT   O
# 1048574  Sentence: 47959     attack   NN   O
#
# [621981 rows x 4 columns]

# %%
count_tags_to_words = train_data.groupby('Tag').apply(lambda x: x.groupby('Word')['Tag'].count().to_dict()).to_dict()
display(count_tags_to_words)
# Out:
# {'B-art': {'300': 2,
#   '@dalailama': 1,
#   'A380s': 1,
#   'AK-47': 1,
#   'AM': 1,
#   'Abu': 2,
#   'Ai': 2,
#   'Akash': 1,
#   'Al': 1,
#   'Anglo-French': 1,
#   'Ansari': 1,
#   'Arabic': 2,
#   'Arc': 1,
#   'Ariana': 1,
#   'Atlantis': 1,
#   'Axum': 1,
#   'Azeri': 1,
#   'BPA': 1,
#   'Balad': 1,
#   'Basilica': 1,
#   'Beijing': 2,
#   'Best': 1,
#   'Bisphenol': 1,
#   'Blades': 1,
#   'Blueberry': 1,
#   'Boeing': 1,
#   'British': 1,
#   'Buddhism': 1,
#   'Cajun': 1,
#   'Camp': 3,
#   'Canal': 4,
#   'Capitol': 1,
#   'China': 1,
#   'Chinook': 1,
#   'Chung': 1,
#   'Creole': 1,
#   'Culture': 1,
#   'Cy': 1,
#   'Da': 1,
#   'Date': 1,
#   'Dejarte': 1,
#   'Democrat': 1,
#   'Destiny': 1,
#   'Dextre': 2,
#   'Didadgah': 1,
#   'Dignity': 1,
#   'Doha': 1,
#   'Economics': 1,
#   'El~Commercio': 1,
#   'Emergency': 1,
#   'Emmy': 1,
#   'Endeavor': 1,
#   'Endeavour': 1,
#   'English': 10,
#   'Facebook': 6,
#   'Ferrari': 1,
#   'For': 1,
#   'Forbes': 3,
#   'Fort': 1,
#   'Four': 1,
#   'Frankenstadion': 1,
#   'French': 2,
#   'GDP': 4,
#   'Georgia': 1,
#   'German': 1,
#   'Google': 2,
#   'Grammy': 1,
#   'Greek': 1,
#   'Grindhouse': 1,
#   'Gross': 1,
#   'Groundhog': 1,
#   'Group': 1,
#   'Group-B': 1,
#   'Gunsmoke': 2,
#   'Happy': 1,
#   'Haqooq-i-Zan': 1,
#   'Heathrow': 1,
#   'Hitch': 1,
#   'Hubble': 4,
#   'Hungarian': 1,
#   'ITV1': 1,
#   'International': 3,
#   'Iron': 1,
#   'Irwindale': 1,
#   'Islam': 3,
#   'Jerusalem': 1,
#   'Journal': 1,
#   'Judaism': 1,
#   'K-4': 1,
#   'Latest': 1,
#   'Linas-Marcoussis': 1,
#   'Literature': 1,
#   'Los': 2,
#   'Lost': 1,
#   'Love': 1,
#   'M': 1,
#   'Maariv': 1,
#   'Manx': 1,
#   'Mars': 1,
#   'McCloud': 1,
#   'Miami': 1,
#   'Mientes': 1,
#   'Miltzow': 2,
#   'MoveOn.org': 1,
#   'Naked': 1,
#   'National': 2,
#   'Nature': 1,
#   'Nevirapine': 1,
#   'Newseum': 1,
#   'No': 1,
#   'Nobel': 4,
#   'Notting': 1,
#   'Okie': 1,
#   'Olympic': 1,
#   'Operation': 1,
#   'Opportunity': 1,
#   'Ouagadougou': 1,
#   'P.S.': 1,
#   'Palme': 1,
#   'Panama': 1,
#   'Pepsi': 1,
#   'Phoenix': 5,
#   'Please': 3,
#   'Pope2You': 1,
#   'Portuguese': 1,
#   'President': 1,
#   'Pul-e-Charkhi': 1,
#   "Qur'an": 1,
#   'Redline': 2,
#   'Rights': 1,
#   'Secrets': 1,
#   'Semana': 1,
#   'Semlow': 2,
#   'Shaheen': 1,
#   'Sidnaya': 2,
#   'Soprano': 1,
#   'Sopranos': 1,
#   'Soul': 1,
#   'SpaceShipOne': 2,
#   'Spanish': 1,
#   'Special': 1,
#   'Stade': 1,
#   'Stadium': 1,
#   'State': 1,
#   'Taba': 1,
#   'Taepodong-2': 1,
#   'Telegraph': 1,
#   'The': 3,
#   'Time': 1,
#   'Times': 1,
#   'Torgelow': 1,
#   'Treaty': 1,
#   'Turkish': 1,
#   'Twitter': 4,
#   'U.N.': 1,
#   'UNKNOWN': 16,
#   'Undercover': 1,
#   'WFP': 1,
#   'Wall': 1,
#   'Wannabe': 1,
#   'Washington': 2,
#   'Western': 1,
#   'Women': 1,
#   'Yedioth': 1,
#   'YouTube': 1,
#   'Z': 1,
#   'Zim': 1,
#   'al-Jazeera': 5,
#   'beatboxing': 1,
#   'bisphenol': 1,
#   'dollar': 1,
#   'euro': 1,
#   'iTunes': 1,
#   'settlement': 1},
#  'B-eve': {'All': 1,
#   'Arbor': 1,
#   'Armistice': 1,
#   'Australian': 5,
#   'Battle': 1,
#   'Beijing': 2,
#   'Bonn': 1,
#   'Candlemas': 1,
#   'Carnival': 1,
#   'Chandrayaan-1': 1,
#   'China': 1,
#   'Christmas': 3,
#   'DN': 1,
#   'Earth': 1,
#   'Euro': 1,
#   'FORTIS': 1,
#   'French': 1,
#   'Grand': 1,
#   'Groundhog': 1,
#   'Heineken': 1,
#   'Hobart': 1,
#   'Holocaust': 1,
#   'Homeless': 1,
#   'Hopman': 2,
#   'Human': 1,
#   'Hurricane': 6,
#   'I': 8,
#   'II': 47,
#   'International': 1,
#   'Katrina': 1,
#   'Kids': 1,
#   'Korean': 1,
#   'Legg': 1,
#   'London': 1,
#   'Madrid': 1,
#   'Mardi': 1,
#   'Mars': 1,
#   'Mass': 3,
#   'Masters': 1,
#   'May': 1,
#   'Medusa': 1,
#   'Nanmadol': 1,
#   'National': 3,
#   'New': 1,
#   'Nottingham': 1,
#   'Olympic': 1,
#   'Olympics': 1,
#   'Operation': 1,
#   'Pakistan': 1,
#   'Paris': 3,
#   'Parma': 1,
#   'Passover': 1,
#   'Peace': 1,
#   'Ramadan': 6,
#   'Revolutionary': 1,
#   'Rolling': 1,
#   'Rosh': 1,
#   'Smithsonian': 1,
#   'Somme': 1,
#   'Summer': 3,
#   'Sydney': 1,
#   'The': 1,
#   'Tiger': 2,
#   'Tropical': 2,
#   'Twilight': 1,
#   'Typhoon': 2,
#   'U.S': 1,
#   'UNKNOWN': 16,
#   'War': 1,
#   'Wilma': 1,
#   'Wimbledon': 1,
#   'Winter': 1,
#   'World': 22,
#   'iftaar': 1},
#  'B-geo': {'"': 1,
#   '-': 2,
#   '02-Jan': 2,
#   '06-Apr': 2,
#   '06-Feb': 1,
#   '06-Jan': 1,
#   '06-Mar': 6,
#   '07-Apr': 1,
#   '07-Jun': 1,
#   '07-May': 1,
#   '09-Feb': 1,
#   '1-0': 3,
#   '202-205-9942': 1,
#   '58th': 1,
#   '70.7': 1,
#   'A.D.': 1,
#   'A.U.': 11,
#   'AC': 1,
#   'AIDS': 1,
#   'Aab-e-Ghum': 1,
#   'Abbas': 1,
#   'Abbassid': 1,
#   'Abdel-Al': 1,
#   'Abdul-Aziz': 1,
#   'Abia': 2,
#   'Abidjan': 5,
#   'Abkhazia': 17,
#   'Abraham': 1,
#   'Abu': 9,
#   'Abuja': 7,
#   'Abyan': 1,
#   'Acapulco': 2,
#   'Accham': 1,
#   'Accra': 3,
#   'Aceh': 12,
#   'Adana': 1,
#   'Addis': 7,
#   'Adel': 1,
#   'Adelie': 1,
#   'Aden': 1,
#   'Adhaim': 1,
#   'Adhamiya': 1,
#   'Adi': 2,
#   'Adijon': 1,
#   'Adjarra': 1,
#   'Adolf': 1,
#   'Adraskan': 1,
#   'Adre': 2,
#   'Adriatic': 1,
#   'Advani': 1,
#   'Adwar': 1,
#   'Aegean': 1,
#   'Afghanistan': 537,
#   'Africa': 112,
#   'African': 49,
#   'Agadez': 1,
#   'Agartala': 1,
#   'Agent': 1,
#   'Agha': 1,
#   'Agriculture': 1,
#   'Ahmad': 1,
#   'Ahmadinejad': 2,
#   'Ahvaz': 1,
#   'Air': 3,
#   'Akhalkalaki': 1,
#   'Akitani-Bob': 2,
#   'Akrotiri': 4,
#   'Al-Ahram': 1,
#   'Al-Fasher': 2,
#   'Al-Hashimi': 1,
#   'Al-Jazeera': 1,
#   'Al-Shara': 1,
#   'Alabama': 4,
#   'Alamodome': 1,
#   'Alaska': 6,
#   'Alawite': 1,
#   'Albania': 6,
#   'Albay': 1,
#   'Alcantara': 1,
#   'Alcoa': 1,
#   'Alec': 1,
#   'Aleppo': 1,
#   'Alessandria': 1,
#   'Alexandria': 2,
#   'Algeria': 16,
#   'Algiers': 1,
#   'Ali': 1,
#   'Alias': 1,
#   'Alishar': 1,
#   'Alitalia': 1,
#   'Alkhanov': 2,
#   'Allahabad': 1,
#   'Allegra': 1,
#   'Almaty': 1,
#   'Altenberg': 1,
#   'Alu': 1,
#   'Alyaty': 1,
#   'Alzheimer': 2,
#   'Amagasaki': 1,
#   'Amarah': 2,
#   'Amazon': 1,
#   'America': 29,
#   'Americas': 1,
#   'Amerli': 1,
#   'Amhara': 1,
#   'Amiriyah': 2,
#   'Amman': 8,
#   'Amona': 1,
#   'Amur': 1,
#   'Anambra': 2,
#   'Anatolia': 2,
#   'Anbar': 9,
#   'Andaman': 1,
#   'Anderson': 1,
#   'Andhra': 3,
#   'Andijan': 5,
#   'Andijon': 3,
#   'Andrhra': 1,
#   'Andry': 2,
#   'Angelus': 1,
#   'Angola': 19,
#   'Angor': 1,
#   'Anguilla': 4,
#   'Anhui': 3,
#   'Anjar': 1,
#   'Anjouan': 1,
#   'Ankara': 29,
#   'Annapolis': 2,
#   'Ansar': 4,
#   'Antananarivo': 1,
#   'Antarctic': 6,
#   'Antarctica': 5,
#   'Antigua': 2,
#   'Anuradhapura': 1,
#   'Anwar': 1,
#   'Anyama': 1,
#   'Aqaba': 2,
#   'Aquino': 2,
#   'Arab': 1,
#   'Arabian': 2,
#   'Arafat': 3,
#   'Arauca': 3,
#   'Arbil': 2,
#   'Arboleda': 1,
#   'Archbishop': 1,
#   'Arctic': 7,
#   'Arero': 2,
#   'Areva': 1,
#   'Argentina': 43,
#   'Arghandab': 2,
#   'Aristide': 1,
#   'Arizona': 8,
#   'Arkansas': 2,
#   'Armando': 1,
#   'Armenia': 8,
#   'Armistice': 1,
#   'Artemisia': 1,
#   'Aruba': 1,
#   'Arusha': 1,
#   'Asadabad': 2,
#   'Ascension': 2,
#   'Asfandyar': 1,
#   'Asghari': 3,
#   'Ashkelon': 3,
#   'Ashraf': 1,
#   'Ashura': 5,
#   'Asia': 80,
#   'Asia-Pacific': 1,
#   'Asian': 2,
#   'Asmara': 1,
#   'Asou': 1,
#   'Assad': 1,
#   'Astana': 2,
#   'Aswat': 2,
#   'Athens': 8,
#   'Atlanta': 10,
#   'Atlantic': 27,
#   'Atomstroyexport': 1,
#   'Auckland': 3,
#   'Augustow': 1,
#   'Aung': 34,
#   'Aurobindo': 1,
#   'Auschwitz': 7,
#   'Austin': 1,
#   'Australia': 75,
#   'Austria': 28,
#   'Avon': 1,
#   'Awantipora': 1,
#   'Axum': 3,
#   'Ayman': 1,
#   'Ayodhya': 1,
#   'Azahari': 1,
#   'Azamiyah': 2,
#   'Azerbaijan': 1,
#   'Azerbaijani': 1,
#   'Azhar': 1,
#   'Azizi': 1,
#   'B': 1,
#   "B'Tselem": 2,
#   'BBC': 1,
#   'BC': 1,
#   'BP': 1,
#   'Bab': 1,
#   'Babil': 1,
#   'Bad': 2,
#   'Badakhshan': 1,
#   'Badakshan': 1,
#   'Badaun': 1,
#   'Badgesty': 1,
#   'Badghis': 4,
#   'Badme': 1,
#   'Badoosh': 1,
#   'Baghdad': 463,
#   'Baghdadi': 1,
#   'Baghlan': 4,
#   'Baghran': 2,
#   'Bago': 1,
#   'Bagram': 4,
#   'Bahamas': 3,
#   'Bahia': 1,
#   'Bahrain': 6,
#   'Baidoa': 12,
#   'Baiji': 2,
#   'Baishiyao': 1,
#   'Baixinglou': 1,
#   'Bajaur': 4,
#   'Bajur': 1,
#   'Bajura': 1,
#   'Bakara': 2,
#   'Bakassi': 1,
#   'Baker': 1,
#   'Bakiyev': 1,
#   'Bakool': 2,
#   'Baku': 3,
#   'Bakwa': 1,
#   'Balad': 11,
#   'Balakot': 1,
#   'Balasingham': 1,
#   'Balata': 2,
#   'Balenciaga': 1,
#   'Bali': 13,
#   'Balkan': 3,
#   'Balkans': 4,
#   'Ballenas': 1,
#   'Balochistan': 2,
#   'Baltic': 1,
#   'Baltim': 1,
#   'Baltimore': 1,
#   'Baluch': 1,
#   'Baluchistan': 22,
#   'Bam': 3,
#   'Bamako': 2,
#   'Ban': 3,
#   'Banaue': 1,
#   'Bancoro': 2,
#   'Banda': 1,
#   'Bandar': 2,
#   'Bandundu': 2,
#   'Bangalore': 6,
#   'Bangkok': 10,
#   'Bangladesh': 36,
#   'Banja': 2,
#   'Banjul': 1,
#   'Bannu': 4,
#   'Baotou': 1,
#   'Baquba': 21,
#   'Baqubah': 2,
#   'Bar': 1,
#   'Bara': 1,
#   'Barakat': 1,
#   'Barbuda': 1,
#   'Barcelona': 4,
#   'Bargal': 2,
#   'Bartolomeo': 1,
#   'Bashar': 1,
#   'Bashir': 1,
#   'Basilan': 2,
#   'Basilica': 3,
#   'Basotho': 1,
#   'Basque': 6,
#   'Basra': 28,
#   'Basutoland': 1,
#   'Batad': 1,
#   'Batna': 1,
#   'Baton': 3,
#   'Batticaloa': 6,
#   'Batu': 2,
#   'Batumi': 1,
#   'Bavaria': 1,
#   'Bay': 4,
#   'Baya': 1,
#   'Bayelsa': 4,
#   'Bayji': 2,
#   'Baylesa': 1,
#   'Bedouin': 1,
#   'Bei': 3,
#   'Beiji': 2,
#   'Beijing': 200,
#   'Beirut': 54,
#   'Beit': 4,
#   'Beitar': 1,
#   'Beja': 3,
#   'Bekaa': 5,
#   'Belarus': 20,
#   'Belet': 1,
#   'Belfast': 2,
#   'Belfort': 1,
#   'Belgium': 24,
#   'Belgrade': 18,
#   'Belize': 5,
#   'Bengal': 1,
#   'Bengali': 1,
#   'Bengalis': 1,
#   'Beni': 2,
#   'Benin': 7,
#   'Benisede': 1,
#   'Benishangul': 1,
#   'Berkeley': 1,
#   'Berlin': 16,
#   'Bermel': 1,
#   'Bermuda': 3,
#   'Bernama': 2,
#   'Bertrand': 1,
#   'Beslan': 7,
#   'Best': 1,
#   'Bethelehem': 1,
#   'Bethlehem': 12,
#   'Bhairahawa': 1,
#   'Bharti': 1,
#   'Bheri': 1,
#   'Bhutan': 4,
#   'Bhutto': 1,
#   'Bihar': 3,
#   'Bikaner': 1,
#   'Bilge': 1,
#   'Biloxi': 1,
#   'Bingol': 2,
#   'Binyamina': 1,
#   'Birkenau': 1,
#   'Birmingham': 2,
#   'Bishkek': 5,
#   'Black': 5,
#   'Blackburn': 1,
#   'Blackhawk': 1,
#   'Blagoveshchensk': 1,
#   'Blanco': 1,
#   'Bogota': 12,
#   'Bogra': 1,
#   'Bolivar': 1,
#   'Bolivia': 37,
#   'Bologna': 1,
#   'Bombay': 4,
#   'Booker': 1,
#   'Borena': 2,
#   'Boris': 1,
#   'Borjomi': 1,
#   'Bormio': 1,
#   'Bosnia': 28,
#   'Bosnia-Herzegovina': 21,
#   'Bossaso': 1,
#   'Boston': 2,
#   'Botswana': 8,
#   'Bouake': 2,
#   'Bouna': 1,
#   'Bouteflika': 1,
#   'Bow': 1,
#   'Braille': 1,
#   'Bralo': 1,
#   'Brasilia': 4,
#   'Brass': 1,
#   'Bratislava': 3,
#   'Brazil': 88,
#   'Brazzaville': 2,
#   'Brisbane': 4,
#   'Bristol': 1,
#   'Britain': 215,
#   'British': 1,
#   'British-Dutch': 1,
#   'Britney': 1,
#   'Broadway': 2,
#   'Brong': 1,
#   'Brooklyn': 1,
#   'Brunei': 5,
#   'Brussels': 29,
#   'Bucharest': 3,
#   'Budapest': 3,
#   'Buddhist': 4,
#   'Bududa': 1,
#   'Budweiser': 1,
#   'Buenos': 2,
#   'Buhriz': 1,
#   'Bujumbura': 2,
#   'Bukavu': 2,
#   'Bula': 1,
#   'Bulgaria': 16,
#   'Bunia': 2,
#   'Bunji': 1,
#   'Buraydah': 1,
#   'Bureau': 2,
#   'Burkina': 6,
#   'Burma': 213,
#   'Burma-Thailand': 1,
#   'Bursa': 1,
#   'Burundi': 11,
#   'Busan': 1,
#   'Bush': 43,
#   'Bushehr': 9,
#   'Buyat': 1,
#   'Cabinet': 6,
#   'Cagliari': 1,
#   'Cairo': 55,
#   'Calabar': 1,
#   'Calcutta': 1,
#   'California': 36,
#   'Cambodia': 21,
#   'Cambridge': 1,
#   'Cameroon': 8,
#   'Camp': 6,
#   'Campo': 1,
#   'Canada': 59,
#   'Canary': 4,
#   'Canberra': 4,
#   'Cancun': 8,
#   'Canterbury': 2,
#   'Cape': 15,
#   'Capitol': 2,
#   'Caqueta': 1,
#   'Carabobo': 1,
#   'Caracas': 43,
#   'Caribbean': 30,
#   'Carson': 1,
#   'Cartagena': 4,
#   'Cartago': 1,
#   'Casablanca': 3,
#   'Caspian': 1,
#   'Cassini': 1,
#   'Castelgandolfo': 1,
#   'Catholic': 7,
#   'Catu': 1,
#   'Caucasus': 2,
#   'Cavalese': 1,
#   'Cayenne': 1,
#   'Cayman': 1,
#   'Central': 31,
#   'Cerveny': 1,
#   'Cesme': 1,
#   'Cetin': 1,
#   'Ceuta': 5,
#   'Ceyhan': 1,
#   'Chaco': 3,
#   'Chad': 51,
#   'Chaman': 1,
#   'Chamber': 1,
#   'Chancellor': 2,
#   'Chandipur': 1,
#   'Chandpur': 1,
#   'Changbei': 1,
#   'Changqi': 1,
#   'Channel': 3,
#   'Chaoyang': 1,
#   'Chaparhar': 1,
#   'Charleston': 3,
#   'Charsadda': 4,
#   'Chattisgarh': 1,
#   'Chavez': 3,
#   'Chechnya': 21,
#   'Cheecha': 1,
#   'Chelyabinsk': 2,
#   'Chemistry': 1,
#   'Chennai': 1,
#   'Cheonan': 1,
#   'Chernobyl': 1,
#   'Chevron': 2,
#   'Chiapas': 1,
#   'Chicago': 8,
#   'Chihuahua': 4,
#   'Chile': 39,
#   'Chilitepic': 1,
#   'China': 571,
#   'Chita': 1,
#   'Chittagong': 2,
#   'Chiweshe': 1,
#   'Cho': 3,
#   'Chodo': 2,
#   'Chora': 1,
#   'Choudhury': 1,
#   'Christ': 1,
#   'Christian': 2,
#   'Christianity': 5,
#   'Christians': 3,
#   'Christmas': 14,
#   'Ciamis': 1,
#   'Cincinnati': 1,
#   'Cirque': 2,
#   'City': 8,
#   'Ciudad': 4,
#   'Clearwater': 1,
#   'Cleveland': 9,
#   'Clichy-sous-Bois': 1,
#   'Clinton': 2,
#   'Clipperton': 1,
#   'Club': 1,
#   'Co.': 1,
#   'Coca-Cola': 2,
#   'Colchester': 1,
#   'Colchis': 1,
#   'Cologne': 2,
#   'Colombia': 132,
#   'Colombo': 13,
#   'Colorado': 6,
#   'Comandante': 2,
#   'Communist': 2,
#   'Congo': 50,
#   'Congotown': 1,
#   'Conn.': 2,
#   'Connecticut': 5,
#   'Conservative': 1,
#   'Cookstown': 1,
#   'Copa': 2,
#   'Copacabana': 1,
#   'Copiapo': 1,
#   'Coral': 1,
#   'Corpus': 2,
#   'Costa': 9,
#   'Cote': 2,
#   'Cotecna': 1,
#   'Cotonou': 2,
#   'Cozumel': 1,
#   'Crawford': 4,
#   'Creole': 1,
#   'Crimea': 5,
#   'Crimean': 1,
#   'Croatia': 35,
#   'Cuba': 136,
#   'Cuzco': 1,
#   'Cyprus': 9,
#   'Czechoslovakia': 4,
#   'D.C.': 7,
#   'DRC': 5,
#   'DVDs': 1,
#   'Dagestan': 4,
#   'Dahab': 1,
#   'Dahomey': 1,
#   'Dahuk': 1,
#   'Dai': 2,
#   'Dakar': 4,
#   'Dakhil': 1,
#   'Daklak': 1,
#   'Dalai': 15,
#   'Dalian': 1,
#   'Dallas': 3,
#   'Damadola': 1,
#   'Damascus': 33,
#   'Dangtu': 1,
#   'Danilo': 1,
#   'Danube': 2,
#   'Danzhou': 1,
#   'Dar': 2,
#   'Daraga': 1,
#   'Darfur': 118,
#   'Datta': 1,
#   'Davos': 2,
#   'Daxing': 1,
#   'Daylam': 1,
#   'Deauville': 1,
#   'Deborah': 1,
#   'Delaware': 3,
#   'Delmas': 1,
#   'Delta': 1,
#   'Democracy': 2,
#   'Democrat': 1,
#   'Democratic': 38,
#   'Den': 1,
#   'Denmark': 20,
#   'Denver': 1,
#   'Dera': 6,
#   'Des': 1,
#   'Desert': 1,
#   'Deshu': 1,
#   'Detlev': 1,
#   'Detroit': 8,
#   'Dhahran': 1,
#   'Dhaka': 7,
#   'Dharamsala': 1,
#   'Dharmsala': 1,
#   'Dhekelia': 3,
#   'Dhusamareb': 1,
#   'Diego': 1,
#   'Dimona': 2,
#   'Disneyland': 4,
#   'Disturbia': 1,
#   'Diwali': 2,
#   'Diwaniyah': 2,
#   'Diyala': 10,
#   'Diyarbakir': 2,
#   'Django': 1,
#   'Djibouti': 15,
#   'Dniester': 1,
#   'Doaba': 1,
#   'Doboj': 1,
#   'Doda': 1,
#   'Dodik': 1,
#   'Doetinchem': 1,
#   'Doghmush': 2,
#   'Doha': 3,
#   'Doi': 1,
#   'Dome': 2,
#   'Dominica': 1,
#   'Dominican': 11,
#   'Domodedovo': 2,
#   'Donetsk': 1,
#   'Dongzhou': 1,
#   'Dora': 1,
#   'Dortmund': 1,
#   'Dow': 1,
#   'Dragmulla': 1,
#   'Drapchi': 1,
#   'Dresden': 1,
#   'Druze': 1,
#   'Dubai': 12,
#   'Dublin': 2,
#   'Dubrovka': 1,
#   'Duekoue': 1,
#   'Dujail': 13,
#   'Duluiya': 1,
#   'Duluiyah': 1,
#   'Duluth': 1,
#   'Duma': 4,
#   'Dunkin': 1,
#   'Durban': 2,
#   'Dushanbe': 2,
#   'Dusseldorf': 1,
#   'Earth': 27,
#   'East': 54,
#   'Easter': 1,
#   'Eastern': 14,
#   'Ebola': 7,
#   'Echeverria': 2,
#   'Economic': 1,
#   'Economics': 1,
#   'Economy': 1,
#   'Ecuador': 38,
#   'Edgware': 1,
#   'Efrat': 1,
#   'Egypt': 118,
#   'Eid': 5,
#   'Ein': 1,
#   'Eindhoven': 1,
#   'Ekici': 1,
#   'El': 10,
#   'El-Maan': 1,
#   'Eldawoody': 1,
#   'Ellsworth': 2,
#   'Elmendorf': 1,
#   'El~Paso': 4,
#   'Emperor': 1,
#   'Endeavouron': 1,
#   'England': 17,
#   'Enrique': 1,
#   'Entebbe': 1,
#   'Equatoria': 2,
#   'Equatorial': 1,
#   'Erez': 1,
#   'Eritrea': 13,
#   'Espirito': 1,
#   'Espiritu': 1,
#   'Estonia': 11,
#   'Ethiopia': 54,
#   'Eugene': 1,
#   'Euphrates': 5,
#   'Europe': 178,
#   'Evangelina': 1,
#   'Everest': 1,
#   'Everglades': 2,
#   'FARC': 5,
#   'Fadhila': 1,
#   'Faizabad': 2,
#   'Falkland': 4,
#   'Falklands': 1,
#   'Fallouj': 1,
#   'Fallujah': 34,
#   'Fame': 2,
#   'Far': 3,
#   'Farah': 6,
#   'Farsi': 2,
#   'Fatah': 44,
#   'Fataki': 1,
#   'Fayoum': 1,
#   'Federated': 2,
#   'Federline': 1,
#   'Ferdinand': 1,
#   'Ferrari': 2,
#   'Fifth': 1,
#   'Finland': 10,
#   'Fiorentina': 1,
#   'Flores': 3,
#   'Florian': 1,
#   'Florida': 50,
#   'Foca': 3,
#   'Forbidden': 1,
#   'Fort': 6,
#   'Fortaleza': 1,
#   'Fouad': 1,
#   'Fox': 1,
#   'France': 188,
#   'Francisco': 7,
#   'Frankfurt': 7,
#   'Free': 1,
#   'French': 1,
#   'Fujian': 2,
#   'Fulani': 1,
#   'Fushun': 2,
#   'Fuzhou': 1,
#   'Ga.': 1,
#   'Gabcikovo': 1,
#   'Gabon': 7,
#   'Gabriele': 1,
#   'Gagra': 1,
#   'Galan': 1,
#   'Gali': 1,
#   'Galle': 2,
#   'Gallup': 1,
#   'Galveston': 1,
#   'Gamma': 1,
#   'Gamsakhurdia': 2,
#   'Ganei': 2,
#   'Ganges': 1,
#   'Ganguly': 1,
#   'Gansu': 1,
#   'Gardasil': 2,
#   'Garissa': 1,
#   'Garmser': 2,
#   'Gaza': 296,
#   'Gazan': 1,
#   'Gazprom': 4,
#   'Gdansk': 2,
#   'Gedi': 2,
#   'Gemelli': 1,
#   'Geneina': 1,
#   'Geneva': 20,
#   'Geofizyka': 1,
#   'Georgia': 75,
#   'Gereida': 1,
#   'Gereshk': 1,
#   'Germanic': 1,
#   'Germany': 172,
#   'Ghad': 1,
#   'Ghalawiya': 1,
#   'Ghana': 16,
#   'Ghangzhou': 1,
#   'Ghazni': 25,
#   'Ghor': 2,
#   'Gikoro': 1,
#   'Gilles': 1,
#   'Gisagara': 1,
#   'Glasgow': 3,
#   'Gleneagles': 3,
#   'Gnassingbe': 4,
#   'Gobernador': 1,
#   'God': 4,
#   'Golan': 5,
#   'Gold': 4,
#   'Golkar': 1,
#   'Good': 1,
#   'Goss': 2,
#   'Gothenburg': 1,
#   'Graceland': 2,
#   'Gran': 2,
#   'Grand': 6,
#   'Granma': 5,
#   'Graz': 1,
#   'Great': 10,
#   'Greece': 18,
#   'Green': 4,
#   'Greenland': 5,
#   'Greenpeace': 3,
#   'Greenville': 1,
#   'Grenada': 4,
#   'Grenoble': 2,
#   'Grigol': 1,
#   'Group-A': 1,
#   'Group-B': 1,
#   'Grozny': 2,
#   'Grytviken': 2,
#   'Guadeloupe': 2,
#   'Guajira': 2,
#   'Guangdong': 13,
#   'Guangxi': 1,
#   'Guangzhou': 8,
#   'Guantanamo': 70,
#   'Guatemala': 19,
#   'Gucci': 1,
#   'Guere': 1,
#   'Guernsey': 1,
#   'Guggenheim': 1,
#   'Guiana': 1,
#   'Guilin': 1,
#   'Guinea': 4,
#   'Guinea-Bissau': 1,
#   'Gujarat': 2,
#   'Guji': 2,
#   'Gulf': 48,
#   'Gulfport': 1,
#   'Gulu': 2,
#   'Guyana': 1,
#   'Göteborg': 1,
#   'HIV': 1,
#   'HPVs': 2,
#   'HRW': 1,
#   'Ha': 1,
#   "Ha'aretz": 1,
#   'Haaretz': 1,
#   'Habbaniya': 1,
#   'Habila': 1,
#   'Habsburg': 1,
#   'Hacari': 1,
#   'Hachijo': 1,
#   'Hadassah': 1,
#   'Haden': 1,
#   'Haditha': 5,
#   'Hadithah': 1,
#   'Haerbaling': 1,
#   'Hafiz': 1,
#   'Hafun': 2,
#   'Hague': 14,
#   'Hainan': 4,
#   'Haisori': 1,
#   'Haiti': 105,
#   'Hajan': 1,
#   'Hakimi': 2,
#   'Hakkari': 1,
#   'Halabja': 4,
#   'Halfun': 1,
#   'Halifax': 2,
#   'Hallandale': 1,
#   'Halloween': 2,
#   'Hamarjajab': 1,
#   'Hamburg': 1,
#   'Hamdania': 3,
#   'Hamdi': 1,
#   'Han': 1,
#   'Hang': 4,
#   'Hangu': 1,
#   'Hangzhou': 1,
#   'Hanjiang': 1,
#   'Hanoi': 10,
#   'Hanover': 2,
#   'Haq': 1,
#   'Harardhere': 1,
#   'Harare': 3,
#   'Harbin': 6,
#   'Hargeisa': 1,
#   'Hariri': 8,
#   'Harithiya': 1,
#   'Hasbrouk': 1,
#   'Hasib': 1,
#   'Hauts-de-Seine': 1,
#   'Havana': 29,
#   'Hawaii': 6,
#   'Hawija': 1,
#   'Heart': 1,
#   'Heathrow': 3,
#   'Hebei': 3,
#   'Hebron': 6,
#   'Heidelberg': 1,
#   'Heihe': 1,
#   'Heiligendamm': 1,
#   'Heilongjiang': 3,
#   'Hellenic': 1,
#   'Helmand': 67,
#   'Helmund': 1,
#   'Helsinki': 1,
#   'Henan': 2,
#   'Herald': 3,
#   'Herat': 7,
#   'Herzegovina': 1,
#   'Hidalgo': 1,
#   'Higüey': 1,
#   'Hilla': 6,
#   'Hillah': 3,
#   'Himalayan': 10,
#   'Himalayas': 2,
#   'Hindu': 6,
#   'Hiroshima': 9,
#   'Hit': 3,
#   'Hizballah': 1,
#   'Hkamti': 1,
#   'Hmawbi': 1,
#   'Ho': 1,
#   'Hodan': 1,
#   'Hokkaido': 1,
#   'Hollywood': 2,
#   'Holocaust': 6,
#   'Holodomor': 1,
#   'Holy': 2,
#   'Honduras': 13,
#   'Hong': 68,
#   'Honiara': 3,
#   'Honshu': 1,
#   'Hoping': 1,
#   'Hormuz': 1,
#   'Horn': 3,
#   'Houston': 15,
#   'Howlwadaag': 1,
#   'Hub': 1,
#   'Hubei': 5,
#   'Hudson': 1,
#   'Hugo': 1,
#   'Hulya': 1,
#   'Hunan': 7,
#   'Hungary': 8,
#   'Hurriyah': 2,
#   'Husaybah': 3,
#   'Hutu': 2,
#   'Hutus': 1,
#   'Huygens': 1,
#   'Hycamtin': 1,
#   'Hyderabad': 4,
#   'ILNA': 1,
#   'IMB': 1,
#   'ISNA': 1,
#   'ITV': 1,
#   'Ibaraki': 1,
#   'Ibb': 1,
#   'Iceland': 6,
#   'Idaho': 1,
#   'Ifugao': 1,
#   'Ignace': 1,
#   'Ilam': 2,
#   'Iles': 1,
#   'Ill.': 1,
#   'Illinois': 5,
#   'Imam': 2,
#   'Imran': 1,
#   'India': 301,
#   'Indian': 36,
#   'Indian-': 1,
#   'Indian-controlled': 5,
#   'Indiana': 3,
#   'Indianapolis': 1,
#   'Indonesia': 129,
#   'Indonesia-Malaysia': 1,
#   'Ingush': 1,
#   'Ingushetia': 4,
#   'Inner': 2,
#   'Insein': 1,
#   'Intelcenter': 1,
#   'Interahamwe': 2,
#   'Interfax': 8,
#   'Interior': 1,
#   'Interlagos': 1,
#   'International': 11,
#   'Interpol': 8,
#   'Iowa': 5,
#   'Ipanema': 1,
#   'Iran': 845,
#   'Iraq': 1099,
#   'Irbil': 1,
#   'Ireland': 11,
#   'Irrawady': 1,
#   'Iscuande': 2,
#   'Isfahan': 5,
#   'Iskandariya': 1,
#   'Iskandariyah': 3,
#   'Islam': 41,
#   'Islamabad': 57,
#   'Islamic': 49,
#   'Islamist': 5,
#   'Israel': 582,
#   'Israel-Gaza': 1,
#   'Israeli': 1,
#   'Issori': 1,
#   'Istanbul': 20,
#   'Itahari': 1,
#   'Italian': 1,
#   'Italy': 68,
#   'Itar-Tass': 1,
#   'Ituri': 6,
#   'Ivanovo': 1,
#   'Ivory': 37,
#   'Izmir': 7,
#   'Izvestia': 1,
#   'JONATHAN': 2,
#   'Jaafari': 1,
#   'Jabaliya': 2,
#   'Jabalya': 1,
#   'Jabel': 1,
#   'Jabella': 1,
#   'Jaca': 1,
#   'Jacksonville': 1,
#   'Jaffna': 13,
#   'Jaghato': 1,
#   'Jaji': 1,
#   'Jakarta': 34,
#   'Jalal': 2,
#   'Jalalabad': 6,
#   'Jalawla': 1,
#   'Jalgaon': 3,
#   "Jam'iyyat": 1,
#   'Jamaat-ud-Dawa': 1,
#   ...},
#  'B-gpe': {'Afghan': 553,
#   'Afghanistan': 42,
#   'Afghans': 28,
#   'African': 156,
#   'Africans': 13,
#   'Albania': 5,
#   'Albanian': 14,
#   'Albanians': 9,
#   'Algerian': 15,
#   'America': 1,
#   'American': 351,
#   'Americans': 132,
#   'Andorra': 5,
#   'Angola': 1,
#   'Angolan': 5,
#   'Antarctic': 1,
#   'Arab': 85,
#   'Arabs': 22,
#   'Argentina': 1,
#   'Argentine': 19,
#   'Argentines': 1,
#   'Armenian': 7,
#   'Armenians': 7,
#   'Aruban': 1,
#   'Asian': 1,
#   'Asians': 3,
#   'Aussie': 1,
#   'Aussies': 2,
#   'Australia': 3,
#   'Australian': 63,
#   'Australians': 11,
#   'Austrian': 16,
#   'Austrians': 2,
#   'Azerbaijan': 19,
#   'Azerbaijani': 1,
#   'Azeri': 5,
#   'Azeris': 4,
#   'Bahamas': 1,
#   'Bahamian': 1,
#   'Bahraini': 2,
#   'Bangladeshi': 13,
#   'Bangladeshis': 3,
#   'Beijing': 3,
#   'Belarusian': 22,
#   'Belgian': 10,
#   'Bengalis': 1,
#   'Benin': 1,
#   'Bermuda': 1,
#   'Bhutanese': 2,
#   'Bolivia': 2,
#   'Bolivian': 17,
#   'Bolivians': 3,
#   'Bosnian': 76,
#   'Brazil': 2,
#   'Brazilian': 37,
#   'Brazilians': 6,
#   'Britain': 3,
#   'British': 370,
#   'Briton': 6,
#   'Britons': 2,
#   'Bulgarian': 8,
#   'Burma': 1,
#   'Burmese': 65,
#   'Burundian': 1,
#   'Burundians': 3,
#   'Cambodian': 8,
#   'Cambodians': 4,
#   'Cameroonian': 1,
#   'Canadian': 54,
#   'Canadians': 11,
#   'Chad': 4,
#   'Chadian': 13,
#   'Chadians': 1,
#   'Chechen': 20,
#   'Chechens': 3,
#   'Chile': 1,
#   'Chilean': 25,
#   'Chileans': 1,
#   'China': 8,
#   'Chinese': 302,
#   'Colombia': 3,
#   'Colombian': 74,
#   'Comoros': 1,
#   'Congo': 1,
#   'Congolese': 29,
#   'Costa': 2,
#   'Crimean': 1,
#   'Croat': 5,
#   'Croatian': 20,
#   'Croats': 7,
#   'Cuban': 96,
#   'Cubans': 16,
#   'Cypriot': 7,
#   'Cyprus': 1,
#   'Czech': 43,
#   'Czechs': 3,
#   'Damascus': 2,
#   'Dane': 1,
#   'Danes': 1,
#   'Danish': 36,
#   'Democratic': 1,
#   'Denmark': 1,
#   'Dominican': 5,
#   'Dominicans': 1,
#   'Dutch': 52,
#   'Ecuador': 4,
#   'Ecuadorian': 5,
#   'Egypt': 1,
#   'Egyptian': 107,
#   'Egyptians': 11,
#   'English': 9,
#   'Eritrean': 12,
#   'Estonian': 1,
#   'Ethiopia': 1,
#   'Ethiopian': 52,
#   'Ethiopians': 12,
#   'Eurasian': 1,
#   'Europeans': 11,
#   'Faroese': 1,
#   'Filipino': 1,
#   'Filipinos': 5,
#   'Finnish': 5,
#   'Finns': 1,
#   'France': 4,
#   'French': 241,
#   'Georgian': 33,
#   'Georgians': 1,
#   'German': 120,
#   'Germans': 10,
#   'Ghanaian': 4,
#   'Gibraltar': 4,
#   'Greek': 36,
#   'Greeks': 2,
#   'Guatemalan': 2,
#   'Guatemalans': 1,
#   'Haiti': 2,
#   'Haitian': 41,
#   'Haitians': 7,
#   'Harare': 1,
#   'Honduran': 4,
#   'Hungarian': 7,
#   'India': 3,
#   'Indian': 170,
#   'Indians': 7,
#   'Indo-Bhutanese': 1,
#   'Indonesia': 1,
#   'Indonesian': 79,
#   'Indonesians': 3,
#   'Iran': 9,
#   'Iranian': 265,
#   'Iranians': 16,
#   'Iraq': 1,
#   'Iraqi': 725,
#   'Iraqis': 86,
#   'Irish': 14,
#   'Israel': 11,
#   'Israeli': 624,
#   'Israelis': 40,
#   'Italian': 79,
#   'Italians': 5,
#   'Ivorian': 6,
#   'Jamaica': 1,
#   'Jamaican': 1,
#   'Jamaicans': 2,
#   'Japan': 6,
#   'Japanese': 133,
#   'Jerusalem': 1,
#   'Jordan': 58,
#   'Jordanian': 2,
#   'Jordanians': 3,
#   'Kashmir': 1,
#   'Kashmiri': 14,
#   'Kashmiris': 1,
#   'Kazakh': 1,
#   'Kazakhs': 1,
#   'Kenya': 1,
#   'Kenyan': 39,
#   'Kenyans': 12,
#   'Kiribati': 2,
#   'Kopra': 1,
#   'Korean': 184,
#   'Koreans': 20,
#   'Kuwait': 2,
#   'Kuwaiti': 10,
#   'Kuwaitis': 1,
#   'Kyrgyz': 11,
#   'Kyrgyzstan': 6,
#   'Lanka': 27,
#   'Lao': 3,
#   'Latvia': 2,
#   'Latvian': 2,
#   'Latvians': 1,
#   'Lebanese': 144,
#   'Liberian': 14,
#   'Liberians': 2,
#   'Libyan': 16,
#   'Liechtenstein': 6,
#   'Lithuania': 1,
#   'Lithuanian': 3,
#   'London': 1,
#   'Los': 2,
#   'Macedonian': 3,
#   'Macedonians': 1,
#   'Madagonia': 2,
#   'Madagonians': 1,
#   'Malaysian': 15,
#   'Maldives': 2,
#   'Mali': 5,
#   'Malian': 1,
#   'Malta': 5,
#   'Mauritanian': 1,
#   'Mauritian': 1,
#   'Melanesian': 1,
#   'Melanesians': 1,
#   'Mexican': 66,
#   'Mexicans': 2,
#   'Mogadishu': 1,
#   'Moldovan': 1,
#   'Mongol': 3,
#   'Mongolia': 1,
#   'Mongolian': 1,
#   'Mongols': 2,
#   'Montenegro': 2,
#   'Monterrey': 2,
#   'Moroccan': 17,
#   'Moroccans': 4,
#   'Namibian': 5,
#   'Nepal': 80,
#   'Nepalese': 18,
#   'Nepali': 3,
#   'New': 5,
#   'Nicaraguan': 6,
#   'Nicaraguans': 1,
#   'Niger': 75,
#   'Nigeria': 2,
#   'Nigerian': 47,
#   'Nigerians': 2,
#   'North': 3,
#   'Norwegian': 22,
#   'Norwegians': 2,
#   'Novakatka': 1,
#   'Novakatkan': 1,
#   'Novakatkans': 2,
#   'Oman': 1,
#   'Pakistan': 12,
#   'Pakistani': 310,
#   'Pakistanis': 21,
#   'Palestinian': 634,
#   'Palestinians': 145,
#   'Panamanian': 2,
#   'Panamanians': 1,
#   'Paraguay': 1,
#   'Persians': 2,
#   'Peru': 5,
#   'Peruvian': 14,
#   'Peruvians': 1,
#   'Philippine': 1,
#   'Poland': 15,
#   'Polish': 46,
#   'Portugal': 2,
#   'Portuguese': 3,
#   'Principality': 1,
#   'Qatar': 1,
#   'Rican': 6,
#   'Romanian': 17,
#   'Russia': 5,
#   'Russian': 330,
#   'Russians': 7,
#   'Rwanda': 2,
#   'Rwandan': 29,
#   'Rwandans': 1,
#   'Salvadoran': 3,
#   'Saudi': 2,
#   'Saudis': 2,
#   'Scottish': 3,
#   'Scythians': 1,
#   'Senegal': 14,
#   'Senegalese': 6,
#   'Seoul': 1,
#   'Serb': 24,
#   'Serbian': 44,
#   'Serbs': 10,
#   'Sikhs': 4,
#   'Singapore': 1,
#   'Slovak': 4,
#   'Slovakia': 2,
#   'Slovakian': 1,
#   'Slovaks': 4,
#   'Slovenes': 2,
#   'Somali': 90,
#   'Somalia': 4,
#   'Somalis': 14,
#   'South': 4,
#   'Spain': 33,
#   'Spaniard': 4,
#   'Spaniards': 4,
#   'Spanish': 77,
#   'Sri': 5,
#   'Sudan': 58,
#   'Sudanese': 97,
#   'Swedes': 2,
#   'Swedish': 21,
#   'Swiss': 29,
#   'Switzerland': 2,
#   'Syria': 2,
#   'Syrian': 112,
#   'Syrians': 4,
#   'Taiwan': 4,
#   'Taiwanese': 8,
#   'Tajik': 2,
#   'Tajikistan': 3,
#   'Tanzanian': 2,
#   'Tashkent': 2,
#   'Tehran': 1,
#   'Thai': 32,
#   'Thailand': 1,
#   'Thais': 1,
#   'Tibetan': 32,
#   'Tibetans': 12,
#   'Turk': 1,
#   'Turkey': 7,
#   'Turkish': 142,
#   'Turkmen': 1,
#   'Turks': 11,
#   'U.S.': 25,
#   'UNKNOWN': 749,
#   'US': 1,
#   'Uganda': 1,
#   'Ugandan': 37,
#   'Ugandans': 4,
#   'Uighurs': 1,
#   'Ukraine': 1,
#   'Ukrainian': 54,
#   'United': 8,
#   'Uruguayan': 2,
#   'Uzbek': 18,
#   'Uzbekistan': 1,
#   'Uzbeks': 4,
#   'Vatican': 2,
#   'Venezuela': 3,
#   'Venezuelan': 174,
#   'Venezuelans': 2,
#   'Vietnam': 1,
#   'Vietnamese': 9,
#   'Washington': 1,
#   'West': 1,
#   'Yemen': 2,
#   'Yemeni': 14,
#   'Yemenis': 1,
#   'Yugoslav': 24,
#   'Yugoslavia': 1,
#   'Zambia': 1,
#   'Zambian': 5,
#   'Zimbabwe': 2,
#   'Zimbabwean': 3,
#   'Zimbabweans': 1,
#   'palestinian': 1},
#  'B-nat': {'2007': 1,
#   'AIDS': 8,
#   'Amur': 1,
#   'Avian': 2,
#   'Bird': 1,
#   'Danielle': 1,
#   'Dissostichus': 1,
#   'Ebola': 1,
#   'Euphausia': 1,
#   'H5N1': 19,
#   'H5N2': 1,
#   'HER-2': 1,
#   'HIV': 2,
#   'Hurricane': 8,
#   'Hurricanes': 5,
#   'Katrina': 30,
#   'Marburg': 15,
#   'Paul': 2,
#   'Rita': 8,
#   'Streptococcus': 1,
#   'TB': 1,
#   'Tropical': 1,
#   'Type': 1,
#   'UNKNOWN': 10,
#   'Wilma': 3,
#   'XDR': 1,
#   'flu': 1,
#   'heart': 1,
#   'influenza': 1,
#   'leukemia': 1},
#  'B-org': {'"': 4,
#   '&': 1,
#   "'s": 21,
#   ',': 8,
#   '-': 4,
#   '1,850': 1,
#   '10-member': 1,
#   '101st': 1,
#   '11': 2,
#   '11th': 1,
#   '19-year-old': 1,
#   '1st': 1,
#   '2004': 1,
#   '2008': 1,
#   '2012': 1,
#   '213': 1,
#   '22-year-old': 1,
#   '250,000-member': 1,
#   '25th': 1,
#   '27-month': 1,
#   '34-nation': 1,
#   '380th': 1,
#   '502nd': 1,
#   '53-nation': 1,
#   '7,000-member': 1,
#   '7-Eleven': 2,
#   '8,000-strong': 1,
#   '?Al-Qaida': 1,
#   'A': 1,
#   'A.K.': 1,
#   'A.L.': 1,
#   'A.U.': 3,
#   'ABC': 10,
#   'ADB': 2,
#   'AFP': 20,
#   'AIA': 2,
#   'AIDS': 27,
#   'AIE': 1,
#   'AIG': 5,
#   'AK': 1,
#   'AM': 1,
#   'AMISOM': 2,
#   'ANC': 4,
#   'ANP': 2,
#   'ANSA': 3,
#   'AOL': 2,
#   'AP': 8,
#   'APEC': 7,
#   'ASB': 1,
#   'ASEAN': 9,
#   'AT&T': 1,
#   'ATP': 1,
#   'AU': 18,
#   'AUC': 2,
#   'Abayi': 1,
#   'Abbas': 2,
#   'Abbasali': 1,
#   'Abbott': 2,
#   'Abd-al-Nisr': 1,
#   'Abdali': 1,
#   'Abdel': 3,
#   'Abdul': 2,
#   'Abdul-Khalim': 1,
#   'Abdulkadir': 3,
#   'Abdulmutallab': 1,
#   'Abiya': 1,
#   'Abizaid': 1,
#   'Abkhaz': 2,
#   'Abqaiq': 3,
#   'Abu': 40,
#   'Abu-Hafs': 1,
#   'Abubakar': 1,
#   'Abuja': 2,
#   'Academy': 3,
#   'Access': 2,
#   'Accordance': 1,
#   'Accra': 1,
#   'Aceh': 8,
#   'Achilles': 1,
#   'Acropolis': 2,
#   'Adelaide': 1,
#   'Adhamiyah': 1,
#   'Admiral': 1,
#   'Advanced': 1,
#   'Advancement': 1,
#   'Aena': 1,
#   'Aero': 1,
#   'Afder': 1,
#   'Afghani': 1,
#   'Afghanistan': 18,
#   'Afren': 1,
#   'African': 15,
#   'Agca': 3,
#   'Agency': 2,
#   'Agha': 1,
#   'Agim': 1,
#   'Agricultural': 1,
#   'Agriculture': 13,
#   'Ahlu': 2,
#   'Ahmad': 1,
#   'Ahmadinejad': 11,
#   'Ahnlund': 1,
#   'Aid': 1,
#   'Air': 13,
#   'Airbus': 10,
#   'Aircraft': 1,
#   'Aiyar': 1,
#   'Ajmal': 1,
#   'Aka': 1,
#   'Akayev': 2,
#   'Akbar': 1,
#   'Akhbar': 1,
#   'Akhtar': 2,
#   'Aksel': 1,
#   'Akylbek': 1,
#   'Al': 15,
#   'Al-Aqsa': 7,
#   'Al-Azhar': 1,
#   'Al-Islam': 1,
#   'Al-Jazeera': 1,
#   'Al-Manar': 1,
#   'Al-Mukmin': 1,
#   'Al-Qaida': 22,
#   'Al-Sadr': 1,
#   'Al-Shabab': 1,
#   'Alaouite': 1,
#   'Alassane': 1,
#   'Alcolac': 1,
#   'Aleksandar': 1,
#   'Alexander': 2,
#   'Algiers': 1,
#   'Ali': 1,
#   'Alireza': 1,
#   'Alito': 9,
#   'All': 2,
#   'All-Star': 1,
#   'Allawi': 2,
#   'Allegiance': 1,
#   'Alliance': 8,
#   'Allied': 3,
#   'Allies': 1,
#   'Alloceans': 1,
#   'Alternative': 1,
#   'Altria': 1,
#   'Alvarezes': 1,
#   'Alvaro': 1,
#   'Alzouma': 1,
#   'Amadou': 2,
#   'Amanullah': 1,
#   'Amarah': 1,
#   'Amazon': 1,
#   'Ambassador': 4,
#   'America': 6,
#   'American': 49,
#   'American-Islamic': 1,
#   'Americas': 5,
#   'Amman': 3,
#   'Amnesty': 14,
#   'Anatolia': 2,
#   'Anatolian': 1,
#   'Andaman': 2,
#   'Andean': 1,
#   'Andrej': 1,
#   'Andres': 2,
#   'Angkor': 1,
#   'Anil': 1,
#   'Ankara': 1,
#   'Ansip': 1,
#   'Antarctic': 2,
#   'Anti-Corruption': 1,
#   'Antoin': 1,
#   'Antwerp': 2,
#   'Apondi': 1,
#   'Apple': 4,
#   'Aquatics': 1,
#   'Arab': 8,
#   'Arafat': 5,
#   'Aral': 1,
#   'Archbishop': 2,
#   'Aref': 1,
#   'Arg': 1,
#   'Argentina': 2,
#   'Ariana': 1,
#   'Ariane': 1,
#   'Arizona': 3,
#   'Arkansas': 1,
#   'Arla': 1,
#   'Arlington': 2,
#   'Armed': 1,
#   'ArmorGroup': 1,
#   'Army': 47,
#   'Arsenal': 1,
#   'Artillery': 1,
#   'Artist': 1,
#   'Asefi': 1,
#   'Asgiriya': 1,
#   'Ashgabat': 1,
#   'Ashin': 1,
#   'Ashkelon': 1,
#   'Asia': 2,
#   'Asia-Pacific': 9,
#   'Asian': 8,
#   'Asif': 2,
#   'Askar': 2,
#   'Aspiazu': 1,
#   'Assad': 1,
#   'Associated': 38,
#   'Associates': 2,
#   'Association': 12,
#   'Aston': 1,
#   'Astros': 2,
#   'Ateret': 1,
#   'Atlanta': 1,
#   'Atmospheric': 1,
#   'Atomic': 1,
#   'Attorney': 1,
#   'Australia': 4,
#   'Australian': 1,
#   'Austria': 3,
#   'Awami': 3,
#   'Ayatollah': 4,
#   'Ayman': 2,
#   'Azima': 2,
#   'Azizuddin': 2,
#   "B'Tselem": 1,
#   'BAINIMARAMA': 1,
#   'BAKIEV': 2,
#   'BBC': 15,
#   'BOA': 1,
#   'BONGO': 1,
#   'BOURGUIBA': 1,
#   'BP': 9,
#   'Baath': 3,
#   'Baathist': 1,
#   'Baba': 1,
#   'Babaker': 1,
#   'Badr': 1,
#   'Bagapsh': 1,
#   'Baghdad': 4,
#   'Bagram': 2,
#   'Bahrain': 6,
#   'Baidoa': 1,
#   'Baja': 1,
#   'Bajaur': 1,
#   'Bajram': 1,
#   'Bakassi': 1,
#   'Bakiyev': 3,
#   'Bakool': 1,
#   'Baluch': 7,
#   'Baluchistan': 5,
#   'Bamako': 1,
#   'Ban': 2,
#   'Banco': 1,
#   'Banda': 1,
#   'Bandar': 1,
#   'Bangkok': 1,
#   'Bangladesh': 7,
#   'Bank': 18,
#   'Banny': 2,
#   'Baquoba': 1,
#   'Barack': 4,
#   'Barakin': 1,
#   'Barcelona': 1,
#   'Barot': 1,
#   'Barrett': 2,
#   'Basayev': 2,
#   'Base': 1,
#   'Basescu': 1,
#   'Basque': 2,
#   'Basra': 1,
#   'Basuto': 1,
#   'Bayfront': 1,
#   'Bayu': 1,
#   'Bedouin': 1,
#   'Beijing': 4,
#   'Beijing-based': 1,
#   'Beirut': 3,
#   'Beit': 3,
#   'Belarus': 13,
#   'Belgium': 2,
#   'Benham': 1,
#   'Benigno': 1,
#   'Benin': 4,
#   'Benito': 1,
#   'Berkeley': 1,
#   'Berlin': 2,
#   'Bermuda': 2,
#   'Bernard': 1,
#   'Bernd': 1,
#   'Bertone': 1,
#   'Besigye': 1,
#   'Beslan': 1,
#   'Betar': 1,
#   'Bhaikaji': 1,
#   'Bharatiya': 1,
#   'Bhat': 1,
#   'Bhubaneshwar': 1,
#   'Bhutan': 1,
#   'Big': 2,
#   'Bild': 1,
#   'Bildnewspaper': 1,
#   'Bilfinger': 1,
#   'Bilis': 1,
#   'Bingu': 1,
#   'Birkenau': 1,
#   'Bitlis': 1,
#   'Blabague': 1,
#   'Black': 6,
#   'Bloemfontein': 1,
#   'Bloomberg': 10,
#   'Blue': 1,
#   'Blues': 2,
#   'Boeing': 18,
#   'Boers': 3,
#   'Bogota': 1,
#   'Boko': 2,
#   'Bolivarian': 1,
#   'Bolivia': 2,
#   'Bolshevik': 1,
#   'Bolton': 3,
#   'Bombay': 1,
#   'Bordeaux': 1,
#   'Bosco': 1,
#   'Boston': 1,
#   'Botswana': 1,
#   'Bounty': 1,
#   'Brandenburg': 1,
#   'Branislav': 1,
#   'Brazil': 5,
#   'Brigadier': 4,
#   'Briston-Myers': 1,
#   'Britain': 3,
#   'British': 26,
#   'Broad': 2,
#   'Broadcasting': 3,
#   'Broncos': 1,
#   'Brookings': 1,
#   'Brotherhood': 6,
#   'Brunei': 2,
#   'Brussels-based': 1,
#   'Buddhist': 5,
#   'Buenos': 3,
#   'Bugti': 1,
#   'Buhriz': 1,
#   'Bulba': 1,
#   'Bulgaria': 1,
#   'Bullitt': 1,
#   'Burma': 9,
#   'Burns': 4,
#   'Burundi': 4,
#   'Bush': 18,
#   'Bush-Clinton': 1,
#   'Business': 1,
#   'C.I.A': 1,
#   'CA': 1,
#   'CAC-40': 1,
#   'CAFTA': 4,
#   'CANTV': 1,
#   'CARE': 3,
#   'CARTOSAT-1': 1,
#   'CBS': 11,
#   'CCAMLR': 1,
#   'CCTV': 1,
#   'CDC': 2,
#   'CEPA': 1,
#   'CFCO': 1,
#   'CH-47': 1,
#   'CIA': 53,
#   'CNBC': 1,
#   'CNN': 22,
#   'CNOOC': 3,
#   'CONCACAF': 1,
#   'CORREA': 1,
#   'COSATU': 2,
#   'CPP': 1,
#   'CPPCC': 2,
#   'CRAB': 1,
#   'CSE': 2,
#   'CSW': 1,
#   'CUD': 3,
#   'Cabinet': 22,
#   'Cable': 3,
#   'Cairo': 2,
#   'California': 8,
#   'Cameroon': 3,
#   'Camila': 1,
#   'Camp': 1,
#   'Canada': 7,
#   'Canadian': 1,
#   'Canal': 1,
#   'Canary': 1,
#   'Canberra': 1,
#   'Cannes': 4,
#   'Cantarell': 1,
#   'Captain': 5,
#   'Caracas': 1,
#   'Cardinal': 1,
#   'Care': 2,
#   'Cargolux': 1,
#   'Carib': 2,
#   'Carnegie': 2,
#   'Carnival': 1,
#   'Caroline': 1,
#   'Carriles': 2,
#   'Carter': 2,
#   'Casablanca': 1,
#   'Casamance': 1,
#   'Caspian': 1,
#   'Cat': 1,
#   'Category': 1,
#   'Caterpillar': 1,
#   'Cathay': 1,
#   'Catholic': 8,
#   'Catholics': 2,
#   'Caucasus': 2,
#   'Cavaliers': 1,
#   'Cayman': 3,
#   'Ceel': 1,
#   'Ceku': 2,
#   'Celsius': 1,
#   'Celtic': 1,
#   'Censorship': 1,
#   'Center': 4,
#   'Central': 36,
#   'Centre': 1,
#   'Cerberus': 1,
#   'Cerkez': 2,
#   'Chaco': 1,
#   'Chaka': 1,
#   'Chalabi': 4,
#   'Challenger': 1,
#   'Champion': 1,
#   'Champions': 1,
#   'Chamrouen': 1,
#   'Chancellor': 2,
#   'Chasseurs-Volontaires': 1,
#   'Chaudhry': 1,
#   'Chechnya': 1,
#   'Chevron': 4,
#   'ChevronTexaco': 2,
#   'Chiapas': 1,
#   'Chihuahua': 1,
#   'China': 31,
#   'Christian': 5,
#   'Christianity': 1,
#   'Christians': 3,
#   'Christmas': 2,
#   'Christopher': 1,
#   'Chrysanthemum': 1,
#   'Chrysler': 1,
#   'Church': 1,
#   'Cimpl': 1,
#   'Cirque': 2,
#   'Citadel': 2,
#   'Cite': 2,
#   'Citgo': 1,
#   'Citi': 1,
#   'Citigroup': 4,
#   'Citroën': 1,
#   'Civil': 6,
#   'Class': 1,
#   'Clearing': 1,
#   'Cleveland': 2,
#   'Climate': 2,
#   'Closer': 1,
#   'Coalition': 4,
#   'Coast': 6,
#   'Cold': 1,
#   'Coleco': 2,
#   'College': 1,
#   'Colombia': 5,
#   'Colombo': 3,
#   'Colonel': 7,
#   'Color': 1,
#   'Colosseum': 1,
#   'Colt': 1,
#   'Combs': 1,
#   'Commander': 1,
#   'Commerce': 15,
#   'Commercial': 1,
#   'Commission': 9,
#   'Commissioner': 3,
#   'Committee': 18,
#   'Commodore': 1,
#   'Commonwealth': 7,
#   'Communications': 2,
#   'Communism': 1,
#   'Communist': 18,
#   'Communists': 1,
#   'Community': 1,
#   'Comoran': 1,
#   'Compaq': 1,
#   'Compay': 1,
#   'Comprehensive': 3,
#   'Concertacion': 1,
#   'Confederation': 2,
#   'Confederations': 3,
#   'Conference': 3,
#   'Cong.': 1,
#   'Congo': 1,
#   'Congress': 114,
#   'Congressional': 2,
#   'Congressional-Executive': 1,
#   'Conoco': 1,
#   'ConocoPhillips': 5,
#   'Conservation': 1,
#   'Conservative': 1,
#   'Constituent': 3,
#   'Constitution': 1,
#   'Constitutional': 1,
#   'Consulate': 1,
#   'Consumer': 1,
#   'Continental': 6,
#   'Convention': 1,
#   'Convergence': 1,
#   'Conviasa': 1,
#   'Cook': 3,
#   'Cooperation': 2,
#   'Coordination': 3,
#   'Coretta': 2,
#   'Corporal': 1,
#   'Corps': 1,
#   'Correo': 1,
#   'Corruption': 2,
#   'Costa': 7,
#   'Costan': 1,
#   'Council': 19,
#   'Country': 2,
#   'Court': 13,
#   'Crab': 1,
#   'Creation': 1,
#   'Creole': 4,
#   'Cricket': 1,
#   'Crips': 1,
#   'Crnojevic': 1,
#   'Croatia': 1,
#   'Crum': 2,
#   'Cuba': 9,
#   'Cubana': 1,
#   'Culture': 2,
#   'Curacao': 2,
#   'Current': 1,
#   'Cyclone': 4,
#   'Cyprus': 15,
#   'DAS': 3,
#   'DAX': 2,
#   'DD': 3,
#   'DEA': 1,
#   'DJ': 1,
#   'DNA': 1,
#   'DOG': 1,
#   'DPP': 1,
#   'DPRK': 2,
#   'DRC': 19,
#   'DTP': 1,
#   'DUC': 1,
#   'Daily': 7,
#   'Daimler': 1,
#   'DaimlerChrysler': 2,
#   'Dakar': 3,
#   'Dalai': 1,
#   'Damascus': 6,
#   'Danube': 1,
#   'Darfur': 32,
#   'Darkazanli': 1,
#   'Darmawan': 1,
#   'Datafolha': 2,
#   'Datapoint': 1,
#   'Davenport': 1,
#   'Davis': 1,
#   'Daw': 1,
#   'Daylam': 1,
#   'Days': 2,
#   'Dayton': 3,
#   'De': 1,
#   'Death': 1,
#   'Debby': 1,
#   'Defense': 59,
#   'Deh': 1,
#   'Delray': 1,
#   'Delta': 27,
#   'Democracy': 1,
#   'Democrat': 5,
#   'Democratic': 40,
#   'Democrats': 7,
#   'Denmark': 5,
#   'Denver': 2,
#   'Department': 10,
#   'Deputy': 4,
#   'Dera': 2,
#   'Desmond': 1,
#   'Deuce': 1,
#   'Development': 3,
#   'Dextre': 1,
#   'Dhanush': 1,
#   'Dhekelia': 1,
#   'Dhi': 1,
#   'Dhiren': 1,
#   'DiCaprio': 1,
#   'Diamond': 1,
#   'Dick': 1,
#   'Diddy': 1,
#   'Die': 1,
#   'Dinesh': 1,
#   'Disasters': 1,
#   'Discovery': 1,
#   'Disease': 1,
#   'Disney': 5,
#   'Diwali': 1,
#   'Diyala': 1,
#   'Dmitry': 1,
#   'Doctors': 2,
#   'Dog': 1,
#   'Dominican': 1,
#   'Don': 1,
#   'Doncasters': 1,
#   'Double': 1,
#   'Douglas': 1,
#   'Dovish': 1,
#   'Draskovic': 1,
#   'Dravid': 2,
#   'DreamWorks': 1,
#   'Drik': 1,
#   'Drug': 2,
#   'Drugs': 1,
#   'Duarte': 1,
#   'Dubai': 6,
#   'Duchess': 2,
#   'Duke': 2,
#   'Dukedom': 1,
#   'Duma': 2,
#   "Dunkin'": 3,
#   'Dwain': 1,
#   'E.U.': 1,
#   'EC': 1,
#   'ECC': 2,
#   'ECOWAS': 3,
#   'EDC': 1,
#   'EDSA': 1,
#   'EEBC': 1,
#   'EEC': 1,
#   'EFTA': 1,
#   'ELN': 12,
#   'EPA': 1,
#   'EPRDF': 3,
#   'ERM2': 1,
#   'ETA': 22,
#   'EU': 244,
#   'EUFOR': 1,
#   'Eagle': 6,
#   'East': 1,
#   'Easter': 1,
#   'Eastern': 2,
#   'Economic': 5,
#   'Ecuador': 2,
#   'Ecumenical': 1,
#   'Eden': 2,
#   'Edison': 1,
#   'Eduard': 1,
#   'Education': 2,
#   'Egypt': 45,
#   'Eid': 3,
#   'Eilat': 1,
#   'Ekmeleddin': 2,
#   'El': 5,
#   'Elah': 1,
#   'Elco': 2,
#   'Election': 3,
#   'Electoral': 1,
#   'Electrical': 1,
#   'Electricidad': 1,
#   'Ellice': 1,
#   'Ellsworth': 1,
#   'Elmar': 1,
#   'El~Tiempo': 1,
#   'El~Universal': 1,
#   'Embassy': 9,
#   'Embera': 1,
#   'Emergency': 1,
#   'Emirates': 1,
#   'Emperor': 2,
#   'Empire': 2,
#   'Emroz': 1,
#   'Endangered': 3,
#   'Energy': 4,
#   'England': 5,
#   'English': 5,
#   'Environmental': 1,
#   'Equatorial': 2,
#   'Equus': 4,
#   'Erbamont': 2,
#   'Erez': 1,
#   'Eritrea': 6,
#   'Eritrea-Ethiopia': 1,
#   'Erkinbayev': 1,
#   'Esa': 1,
#   'Esmatullah': 1,
#   'Esperanza': 1,
#   'Essebar': 1,
#   'Estonia': 1,
#   'Ethiopia': 8,
#   'Ethiopian': 4,
#   'Ettore': 1,
#   'Euphrates': 2,
#   'Euro': 1,
#   'European': 307,
#   'European-built': 1,
#   'Europol': 2,
#   'Eutelsat': 1,
#   'Eve': 1,
#   'Eveready': 1,
#   'Everest': 1,
#   'Evo': 1,
#   'Executive': 3,
#   'Expediency': 1,
#   'External': 1,
#   'Extractive': 1,
#   'Exxon': 1,
#   'ExxonMobil': 7,
#   'Ezzedine': 1,
#   'F-4': 1,
#   'FAO': 5,
#   'FARC': 35,
#   'FATAs': 1,
#   'FBI': 17,
#   'FDA': 4,
#   'FEMA': 7,
#   'FIFA': 21,
#   'FM': 2,
#   'FNJ': 1,
#   'FNL': 1,
#   'FOWLER': 1,
#   'FOX': 2,
#   'FSG': 1,
#   'Fabrizio': 1,
#   'Facebook': 1,
#   'Falash': 2,
#   'Falcons': 1,
#   'Falklands': 1,
#   'Falun': 1,
#   'Family': 1,
#   'Farewell': 1,
#   'Faroe': 1,
#   'Fatah': 24,
#   'Fatah-controlled': 1,
#   'Father': 1,
#   'Fatma': 1,
#   'Faure': 1,
#   'Fayaz': 1,
#   'Fazul': 1,
#   'Fed': 4,
#   'Federal': 23,
#   'Federally': 2,
#   'Federated': 1,
#   'Federation': 10,
#   'Female': 1,
#   'Feminine': 1,
#   'Fiat': 2,
#   'Fidelity': 1,
#   'Figueredo': 3,
#   'Filmyard': 3,
#   'Finance': 1,
#   'Financial': 5,
#   'Finland': 3,
#   'Fire': 2,
#   'First': 3,
#   'Fisher-Price': 1,
#   'Floribert': 1,
#   'Florida': 1,
#   'Folha': 1,
#   'Fonseka': 2,
#   'Food': 5,
#   'Football': 3,
#   'Ford': 8,
#   'Foreign': 57,
#   'Fortinet': 1,
#   'Foundation': 1,
#   'Fox': 12,
#   'Framework': 1,
#   'France': 12,
#   'Franken': 1,
#   'Franz': 1,
#   'Free': 8,
#   'Freedom': 3,
#   'Frelimo': 1,
#   'French': 17,
#   'Frenchman': 1,
#   'Fuji': 3,
#   'Fund': 2,
#   'Future': 3,
#   'G-20': 3,
#   'G-8': 4,
#   'G-CAPP': 1,
#   'G7': 2,
#   'G8': 4,
#   'GAO': 2,
#   'GE': 2,
#   'GEO': 1,
#   'GM': 11,
#   "GM's": 1,
#   'GOLDING': 1,
#   'GONSALVES': 1,
#   'GSPC': 1,
#   'Gabon': 7,
#   'Gadhafi': 1,
#   'Galle': 1,
#   'Gallup': 1,
#   'Gambia': 1,
#   'Gambira': 1,
#   'Gamsakhurdia': 1,
#   'Garikoitz': 1,
#   'Gasene': 1,
#   'Gates': 1,
#   'Gaza': 25,
#   'Gazprom': 17,
#   'General': 94,
#   'Geneva': 1,
#   'Geological': 1,
#   'Georgetown': 1,
#   'Georgia': 5,
#   'Germany': 8,
#   'Getty': 1,
#   'Ghad': 1,
#   'Ghalib': 1,
#   'Ghana': 1,
#   'Gholam': 1,
#   'Ghorbanpour': 1,
#   'Ghulam': 2,
#   'Gibraltarians': 1,
#   'Gijs': 1,
#   'Gilbert': 2,
#   'Gilead': 1,
#   'Giro': 1,
#   'GlaxoSmithKline': 2,
#   'Gloria': 1,
#   'Gnassingbe': 6,
#   'Gojko': 1,
#   'Golan': 1,
#   'Golden': 2,
#   'Goldman': 1,
#   'Golo': 1,
#   'Gomoa': 1,
#   'Goodwill': 1,
#   'Google': 12,
#   'Gordon': 1,
#   'Gotovina': 1,
#   'Government': 4,
#   'Grammy': 1,
#   'Gran': 1,
#   'Grand': 5,
#   'Granma': 1,
#   'Great': 7,
#   'Greece': 5,
#   'Green': 6,
#   'Greenpeace': 1,
#   'Greens': 2,
#   'Grenada': 2,
#   'Grenadines': 4,
#   'Grill': 1,
#   'Grossman': 1,
#   'Group': 26,
#   'Growth': 2,
#   'Guam': 1,
#   'Guard': 1,
#   'Guardian': 6,
#   'Guatemala': 3,
#   'Guber': 1,
#   'Guinea': 1,
#   'Guinness': 1,
#   'Gulag': 2,
#   'Gulbuddin': 1,
#   'Gustav': 1,
#   'Guys': 1,
#   'Gypsies': 1,
#   'Gypsy': 1,
#   'H': 1,
#   'H&M': 1,
#   'H5': 1,
#   'HAMAS': 2,
#   'HAMSAT': 2,
#   'HIPC': 7,
#   'HIV': 18,
#   'HMAS': 1,
#   'HP': 1,
#   'HRW': 4,
#   'Habib': 2,
#   'Hadassah': 1,
#   'Hadson': 1,
#   'Hague': 8,
#   'Hainan': 1,
#   'Haiti': 2,
#   'Haitian-born': 1,
#   'Hajj': 1,
#   'Hakimullah': 1,
#   'Hallwood': 1,
#   'Halo': 1,
#   'Hamas': 253,
#   'Hamesh': 1,
#   'Hampton': 1,
#   'Hang': 1,
#   'Haniyeh': 1,
#   'Hanoi': 1,
#   'Haradinaj': 2,
#   'Harare': 3,
#   'Hargreaves': 1,
#   'Hariri': 1,
#   'Haroon': 1,
#   'Hart': 2,
#   'Harvard': 2,
#   'Hassan': 1,
#   'Hasyim': 1,
#   'Hatf': 2,
#   'Havana': 1,
#   'Hawiye': 1,
#   'Hazel': 1,
#   'Hazem': 1,
#   'Health': 19,
#   'Hear': 1,
#   'Heathrow': 1,
#   'Heavily': 3,
#   'Hekmatyar': 2,
#   'Helmand': 1,
#   'Help': 1,
#   'Hennes': 1,
#   'Herald': 4,
#   'Herat': 1,
#   'Heroes': 1,
#   'Hexogen': 1,
#   'Hezbollah': 75,
#   'High': 20,
#   'Highly': 4,
#   'Hill': 1,
#   'Hillary': 1,
#   'Hindu': 4,
#   'Hindus': 2,
#   'Hizbul': 2,
#   'Hofstad': 1,
#   'Holocaust': 3,
#   'Holy': 9,
#   'Home': 1,
#   'Homeland': 2,
#   'Honduras': 4,
#   'Hong': 1,
#   'HornAfrik': 1,
#   'Hornets': 2,
#   'Hosoda': 1,
#   'Host': 2,
#   'Hotmail': 1,
#   'House': 38,
#   'Houston': 1,
#   'Howlwadaag': 1,
#   'Hubble': 8,
#   'Hudur': 2,
#   'Hughes': 1,
#   'Hulya': 1,
#   'Human': 31,
#   'Humanitarian': 1,
#   'Hungarian': 1,
#   'Hungary': 7,
#   'Hurricanes': 1,
#   'Hurriya': 1,
#   'Hurriyat': 3,
#   'Huthi': 1,
#   'Hutu': 12,
#   'Hutus': 1,
#   'Huygens': 1,
#   'Hycamtin': 1,
#   'Hyundai': 1,
#   'IAEA': 45,
#   'IAPA': 1,
#   'ICC': 1,
#   'ICG': 1,
#   'ICRC': 3,
#   'IDB': 1,
#   'IDF': 1,
#   'IDPs': 1,
#   'IEDs': 1,
#   'IISS': 1,
#   'ILO': 3,
#   'IMF': 52,
#   'IMF-World': 1,
#   'IOC': 10,
#   'IRA': 8,
#   'IRNA': 13,
#   'ISAF': 9,
#   'ISRO': 1,
#   'ITU': 1,
#   'Idi': 1,
#   'Idolwinner': 1,
#   'Iftikhar': 1,
#   'Il': 2,
#   'Ilham': 1,
#   'Illinois': 4,
#   'Imad': 1,
#   'Imam': 2,
#   'Imperial': 2,
#   'Inaugural': 1,
#   'Inayatullah': 1,
#   'Independent': 6,
#   'India': 31,
#   ...},
#  'B-per': {"'": 1,
#   '-': 1,
#   '50': 1,
#   'ABHISIT': 1,
#   'AZALI': 2,
#   'Aalam': 1,
#   'Abbas': 1,
#   'Abdallah': 1,
#   'Abdel': 7,
#   'Abdelrahman': 1,
#   'Abdikadir': 1,
#   'Abdolvahed': 1,
#   'Abdouramane': 1,
#   'Abdul': 24,
#   'Abdulhamid': 1,
#   'Abdulla': 1,
#   'Abdullah': 14,
#   'Abdullahi': 2,
#   'Abed': 2,
#   'Abercrombie': 1,
#   'Abhisit': 1,
#   'Abraham': 2,
#   'Abramoff': 3,
#   'Absalon': 2,
#   'Abu': 35,
#   'Abuja': 2,
#   'Abul': 1,
#   'Achakzai': 1,
#   'Acosta': 1,
#   'Adam': 10,
#   'Adan': 1,
#   'Addis': 3,
#   'Adel': 1,
#   'Adnan': 3,
#   'Adolf': 2,
#   'Adolfo': 1,
#   'Adrian': 1,
#   'Adriano': 2,
#   'Adrienne': 1,
#   'Afghanistan': 2,
#   'Agassi': 1,
#   'Agha': 1,
#   'Agnes': 1,
#   'Ahmad': 5,
#   'Ahmadinejad': 1,
#   'Ahmed': 19,
#   'Ahmedou': 1,
#   'Ahn': 1,
#   'Ahtisaari': 1,
#   'Aidar': 1,
#   'Aijalon': 1,
#   'Aiko': 1,
#   'Aip': 1,
#   'Aisha': 3,
#   'Akbar': 2,
#   'Akerson': 2,
#   'Akhrorkhodzha': 1,
#   'Al': 4,
#   'Al-Ghoul': 1,
#   'Al-Majid': 1,
#   'Al-Rishawi': 1,
#   'Al-Sadr': 3,
#   'Al-Shihri': 1,
#   'Al-Zarqawi': 1,
#   'Al-Zawahiri': 2,
#   'Alabama': 1,
#   'Alamzai': 1,
#   'Alan': 10,
#   'Alassane': 4,
#   'Albert': 2,
#   'Alberto': 4,
#   'Aleem': 1,
#   'Alejandro': 2,
#   'Aleksandar': 1,
#   'Aleksander': 1,
#   'Alex': 2,
#   'Alexander': 16,
#   'Alexandre': 1,
#   'Alexei': 2,
#   'Alexeyev': 1,
#   'Alexi': 1,
#   'Alfred': 3,
#   'Alfredo': 1,
#   'Ali': 43,
#   'Alistair': 1,
#   'Aliu': 1,
#   'Allah': 1,
#   'Allawi': 1,
#   'Alliot-Marie': 1,
#   'Alonso': 2,
#   'Alpha': 6,
#   'Alstom': 1,
#   'Alvarez': 1,
#   'Alvaro': 3,
#   'Amanullah': 1,
#   'Ambassador': 1,
#   'Amelie': 2,
#   'Amer': 2,
#   'Amir': 3,
#   'Amman': 1,
#   'Amr': 3,
#   'Amrullah': 1,
#   'Ana': 1,
#   'Anabel': 3,
#   'Anand': 1,
#   'Anat': 1,
#   'Anatoliy': 1,
#   'Anatoly': 3,
#   'Ancic': 1,
#   'Anders': 3,
#   'Anderson': 1,
#   'Andras': 3,
#   'Andre': 6,
#   'Andreas': 1,
#   'Andrei': 1,
#   'Andres': 4,
#   'Andresen': 1,
#   'Andrew': 12,
#   'Andriy': 1,
#   'Andrus': 1,
#   'Andy': 3,
#   'Angel': 1,
#   'Angela': 8,
#   'Angelina': 1,
#   'Anil': 2,
#   'Anita': 1,
#   'Ann': 3,
#   'Anna': 2,
#   'Anna-Lena': 2,
#   'Annan': 1,
#   'Annie': 1,
#   'Ansar': 2,
#   'Anthony': 2,
#   'Antoine': 2,
#   'Anton': 1,
#   'Antonin': 1,
#   'Antonio': 6,
#   'Anwar': 1,
#   'Anwarul': 1,
#   'Aphaluck': 1,
#   'Arab': 3,
#   'Arafat': 1,
#   'Archbishop': 1,
#   'Ariel': 25,
#   'Aristide': 2,
#   'Arjun': 1,
#   'Armando': 1,
#   'Armin': 1,
#   'Arnold': 2,
#   'Arsala': 3,
#   'Arturo': 2,
#   'Asad': 1,
#   'Asadabad': 1,
#   'Asadullah': 1,
#   'Asafa': 1,
#   'Asef': 1,
#   'Ashley': 2,
#   'Ashr': 1,
#   'Ashwell': 1,
#   'Asif': 2,
#   'Aslan': 2,
#   'Aso': 2,
#   'Assadullah': 1,
#   'Augusto': 7,
#   'Aung': 15,
#   'Austin': 1,
#   'Austria': 1,
#   'Auwaerter': 1,
#   'Avigdor': 2,
#   'Avril': 1,
#   'Ayad': 2,
#   'Ayatollah': 9,
#   'Ayman': 15,
#   'Ayoub': 1,
#   'Azahari': 4,
#   'Azimbek': 1,
#   'Aziz': 1,
#   'Azizullah': 1,
#   'Azmi': 1,
#   'BAKIEV': 1,
#   'BALAGUER': 1,
#   'BEN': 1,
#   'BOEDIONO': 1,
#   'BOSCH': 1,
#   'Bab': 1,
#   'Babar': 1,
#   'Bachelet': 6,
#   'Bagosora': 2,
#   'Bahonar': 1,
#   'Baitullah': 1,
#   'Bajram': 2,
#   'Baki': 2,
#   'Baku': 1,
#   'Bali': 2,
#   'Bambang': 4,
#   'Ban': 3,
#   'Banda': 1,
#   'Bandar': 1,
#   'Banderas': 1,
#   'Bangkok': 1,
#   'Barack': 12,
#   'Barak': 2,
#   'Barghouti': 6,
#   'Barham': 1,
#   'Barinov': 3,
#   'Barney': 1,
#   'Barre': 1,
#   'Barretto': 2,
#   'Barron': 1,
#   'Barroso': 1,
#   'Barry': 5,
#   'Barzan': 1,
#   'Barzani': 4,
#   'Bashar': 3,
#   'Bassel': 1,
#   'Bauer': 1,
#   'Bayan': 3,
#   'Beatle': 1,
#   'Beckett': 3,
#   'Beckham': 3,
#   'Beerenberg': 1,
#   'Beethoven': 2,
#   'Behnam': 1,
#   'Belgrade': 1,
#   'Belize': 2,
#   'Ben': 5,
#   'Ben-Eliezer': 1,
#   'Benazir': 2,
#   'Benedict': 25,
#   'Benedicto': 1,
#   'Benesova': 2,
#   'Benigno': 1,
#   'Benita': 2,
#   'Benito': 2,
#   'Benjamin': 9,
#   'Bennett': 3,
#   'Benon': 2,
#   'Berdych': 1,
#   'Berenson': 3,
#   'Bergersen': 2,
#   'Bergman': 1,
#   'Berkovsky': 1,
#   'Berman': 1,
#   'Bermet': 1,
#   'Bernanke': 4,
#   'Bernard': 10,
#   'Bernie': 1,
#   'Bert': 1,
#   'Bertie': 2,
#   'Besigye': 3,
#   'Besir': 1,
#   'Betancourt': 1,
#   'Betty': 2,
#   'Bhutan': 2,
#   'Bhutto': 1,
#   'Bible': 1,
#   'Biden': 4,
#   'Bihari': 1,
#   'Bikindi': 2,
#   'Bild': 1,
#   'Bilfinger': 1,
#   'Bill': 17,
#   'Bin': 3,
#   'Bin-Laden': 1,
#   'Bisengimina': 1,
#   'Bishara': 2,
#   'Bishkek': 1,
#   'Bishop': 2,
#   'Bitar': 1,
#   'Blair': 1,
#   'Blake': 1,
#   'Blanco': 1,
#   'Blechschmidt': 1,
#   'Blonska': 1,
#   'Blumenthal': 1,
#   'Bob': 6,
#   'Bobbie': 1,
#   'Bobby': 1,
#   'Bode': 3,
#   'Bodman': 2,
#   'Boeta': 1,
#   'Bolivar': 4,
#   'Bollea': 2,
#   'Bolt': 1,
#   'Bombardier': 1,
#   'Boris': 4,
#   'Boroujerdi': 2,
#   'Botimar': 1,
#   'Boucher': 2,
#   'Boudhiba': 2,
#   'Bouyeri': 2,
#   'Brad': 4,
#   'Brammertz': 1,
#   'Bravo': 1,
#   'Brendan': 1,
#   'Brent': 8,
#   'Brett': 1,
#   'Brian': 7,
#   'Brig.': 1,
#   'Britney': 6,
#   'Brown': 5,
#   'Brownfield': 1,
#   'Bruce': 2,
#   'Bruhin': 1,
#   'Bruno': 1,
#   'Bryan': 3,
#   'Buechel': 1,
#   'Buenaventura': 1,
#   'Buenos': 1,
#   'Buffett': 1,
#   'Burkina': 4,
#   'Burt': 1,
#   'Bush': 37,
#   'Busta': 2,
#   'Butch': 1,
#   'Bwakira': 1,
#   'C.W.': 1,
#   'CAMARA': 1,
#   'CEAUSESCU': 1,
#   'COLUMBUS': 1,
#   'Cabinet': 2,
#   'Cairo': 3,
#   'Calvin': 1,
#   'Camara': 2,
#   'Camel': 1,
#   'Cameron': 1,
#   'Camilla': 5,
#   'Camp': 3,
#   'Campbell': 3,
#   'Canberra': 1,
#   'Capt.': 1,
#   'Captain': 2,
#   'Caraballo': 1,
#   'Caracas': 1,
#   'Cardenas': 1,
#   'Cardinal': 6,
#   'Carl': 2,
#   'Carla': 4,
#   'Carli': 1,
#   'Carlos': 6,
#   'Carmona': 2,
#   'Carol': 9,
#   'Carolyn': 7,
#   'Carriles': 1,
#   'Carroll': 6,
#   'Casey': 1,
#   'Cassation': 1,
#   'Castel': 1,
#   'Castro': 2,
#   'Catalonia': 1,
#   'Cate': 2,
#   'Catherine': 4,
#   'Catholic': 6,
#   'Cathy': 1,
#   'Celia': 1,
#   'Celine': 1,
#   'Celsius': 1,
#   'Celso': 1,
#   'Chahine': 1,
#   'Chalit': 1,
#   'Chambers': 1,
#   'Chambliss': 1,
#   'Chancellor': 21,
#   'Chandler': 1,
#   'Chang': 1,
#   'Charles': 6,
#   'Charm': 4,
#   'Charon': 1,
#   'Chaudhry': 7,
#   'Chavez': 8,
#   'Cheek': 3,
#   'Chela': 1,
#   'Chelsea': 2,
#   'Chen': 2,
#   'Chenembiri': 1,
#   'Cheney': 13,
#   'Cher': 1,
#   'Chertoff': 6,
#   'Chester': 2,
#   'Chevron': 2,
#   'Chiang': 1,
#   'Chiapolino': 1,
#   'Chidambaram': 1,
#   'Chilumpha': 5,
#   'Chinggis': 1,
#   'Cho': 1,
#   'Choe': 1,
#   'Choi': 1,
#   'Chosun': 1,
#   'Chris': 7,
#   'Christ': 1,
# ...
#   'purely': 1,
#   'quake': 1,
#   'quarter': 16,
#   'quarters': 1,
#   'rainfall': 1,
#   're-run': 2,
#   'recess': 1,
#   'referendum': 4,
#   'regardless': 1,
#   'regions': 1,
#   'release': 2,
#   'remembrance': 1,
#   'revelry': 1,
#   'revolution': 2,
#   'riot': 1,
#   'rounds': 1,
#   'run-off': 1,
#   'runoff': 1,
#   'rush': 1,
#   'season': 5,
#   'seasons': 1,
#   'second': 4,
#   'sentence': 1,
#   'separatist': 1,
#   'session': 2,
#   'seven': 1,
#   'seventh': 4,
#   'several': 5,
#   'shantytown': 1,
#   'shortfall': 1,
#   'shuttle': 1,
#   'since': 11,
#   'six': 18,
#   'six-party': 1,
#   'soccer': 1,
#   'socialism': 1,
#   'sporadic': 1,
#   'straight': 10,
#   'subway': 1,
#   'summer': 2,
#   'summit': 3,
#   'surplus': 1,
#   'take-over': 2,
#   'term': 5,
#   'than': 15,
#   'that': 21,
#   'thaw': 1,
#   'the': 3,
#   'then': 2,
#   'third': 4,
#   'this': 1,
#   'thousand': 1,
#   'three': 31,
#   'three-month': 1,
#   'through': 14,
#   'time': 27,
#   'to': 65,
#   'today': 8,
#   'tour': 1,
#   'townships': 1,
#   'treaty': 1,
#   'trek': 1,
#   'two': 52,
#   'unrest': 1,
#   'until': 6,
#   'uprising': 1,
#   'victory': 1,
#   'violence': 5,
#   'vote': 11,
#   'warfare': 1,
#   'weekend': 2,
#   'wickets': 1,
#   'wild': 2,
#   'working-age': 1,
#   'yesterday': 1,
#   '\x97': 1},
#  'O': {'!': 16,
#   '"': 2377,
#   '#': 11,
#   '#NAME?': 1,
#   '$': 761,
#   '%': 290,
#   "'": 234,
#   "'80s": 1,
#   "'T": 1,
#   "'d": 2,
#   "'ll": 4,
#   "'m": 6,
#   "'n": 1,
#   "'re": 3,
#   "'s": 6854,
#   "'ve": 3,
#   '(': 436,
#   ')': 437,
#   ',': 21311,
#   '-': 546,
#   '--': 54,
#   '.': 31127,
#   '..': 1,
#   '...': 11,
#   '.tv': 1,
#   '/': 20,
#   '0-3': 1,
#   '0.01': 1,
#   '0.050474537': 1,
#   '0.051655093': 1,
#   '0.060092593': 1,
#   '0.068263889': 1,
#   '0.068275463': 1,
#   '0.068472222': 1,
#   '0.08': 2,
#   '0.1': 2,
#   '0.110474537': 1,
#   '0.110625': 1,
#   '0.17': 1,
#   '0.19': 1,
#   '0.193': 1,
#   '0.2': 5,
#   '0.3': 2,
#   '0.35': 1,
#   '0.4': 3,
#   '0.5': 4,
#   '0.55': 1,
#   '0.6': 2,
#   '0.65': 1,
#   '0.7': 2,
#   '0.8': 3,
#   '0.9': 1,
#   '01-Feb': 1,
#   '01-Jan': 4,
#   '01-Jun': 2,
#   '02-Feb': 3,
#   '02-Jan': 8,
#   '02-Jun': 1,
#   '02-May': 1,
#   '03-Apr': 2,
#   '03-Feb': 3,
#   '03-Jan': 2,
#   '03-Jun': 5,
#   '03-Mar': 1,
#   '04-Jan': 1,
#   '04-Jun': 6,
#   '05-Apr': 2,
#   '05-Jan': 1,
#   '05-Jul': 2,
#   '05-Mar': 1,
#   '06-Apr': 23,
#   '06-Feb': 16,
#   '06-Jan': 9,
#   '06-Jul': 3,
#   '06-Mar': 13,
#   '07-Aug': 1,
#   '07-Feb': 1,
#   '07-Jun': 11,
#   '07-May': 11,
#   '09-Aug': 1,
#   '09-Nov': 1,
#   '1': 48,
#   '1,00,000': 23,
#   '1,000': 68,
#   '1,000-meter': 2,
#   '1,000-year': 1,
#   '1,04,586': 1,
#   '1,06,591': 1,
#   '1,07,000': 1,
#   '1,09,000': 1,
#   '1,10,000': 3,
#   '1,100': 6,
#   '1,125': 1,
#   '1,15,000': 1,
#   '1,17,000': 1,
#   '1,170': 1,
#   '1,20,000': 1,
#   '1,200': 9,
#   '1,247': 1,
#   '1,250': 3,
#   '1,26,976': 1,
#   '1,27,000': 1,
#   '1,27,910': 1,
#   '1,275': 1,
#   '1,30,000': 5,
#   '1,300': 13,
#   '1,34,503': 1,
#   '1,35,000': 1,
#   '1,38,000': 2,
#   '1,40,000': 5,
#   '1,400': 7,
#   '1,44,000': 1,
#   '1,460': 1,
#   '1,50,000': 12,
#   '1,500': 14,
#   '1,55,000': 1,
#   '1,59,000': 1,
#   '1,60,000': 2,
#   '1,600': 7,
#   '1,600-member': 1,
#   '1,630': 1,
#   '1,64,000': 1,
#   '1,69,000': 1,
#   '1,70,000': 2,
#   '1,700': 9,
#   '1,700-year-old': 1,
#   '1,72,000': 1,
#   '1,75,000': 1,
#   '1,80,000': 12,
#   '1,800': 5,
#   '1,82,000': 1,
#   '1,90,000': 1,
#   '1,900': 2,
#   '1,950': 1,
#   '1-0': 7,
#   '1-to-1': 1,
#   '1.06': 2,
#   '1.08': 1,
#   '1.1': 4,
#   '1.125': 2,
#   '1.17': 1,
#   '1.2': 9,
#   '1.224': 1,
#   '1.24': 1,
#   '1.26': 1,
#   '1.27': 1,
#   '1.28.19': 1,
#   '1.2927': 1,
#   '1.3': 12,
#   '1.31': 1,
#   '1.32': 2,
#   '1.329': 1,
#   '1.34': 1,
#   '1.35': 1,
#   '1.4': 7,
#   '1.459': 1,
#   '1.48': 1,
#   '1.5': 26,
#   '1.55': 1,
#   '1.6': 3,
#   '1.64': 1,
#   '1.65': 3,
#   '1.7': 5,
#   '1.76': 2,
#   '1.8': 6,
#   '1.9': 7,
#   '1.92': 1,
#   '10': 201,
#   '10,00,000': 1,
#   '10,000': 43,
#   '10,000-square-kilometer': 1,
#   '10,000-strong': 1,
#   '10-Dec': 1,
#   '10-Jan': 1,
#   '10-day': 2,
#   '10-kilometer': 2,
#   '10-meter': 1,
#   '10-million': 1,
#   '10-month-old': 1,
#   '10-nation': 2,
#   '10-percent': 2,
#   '10-person': 1,
#   '10-point': 1,
#   '10-story': 1,
#   '10-to-eight': 1,
#   '10-week': 1,
#   '10-year': 9,
#   '10-year-old': 3,
#   '10-years-ago': 1,
#   '10.2': 1,
#   '10.5': 2,
#   '10.8': 1,
#   '100': 121,
#   '100-meter': 5,
#   '100-meters': 1,
#   '100-thousand': 1,
#   '100-year': 1,
#   '100-year-old': 1,
#   '1000': 4,
#   '1004': 1,
#   '101': 3,
#   '102': 4,
#   '102-member': 1,
#   '103': 4,
#   '103.05': 1,
#   '1030': 1,
#   '104': 6,
#   '104.1': 1,
#   '105': 8,
#   '105.97': 1,
#   '1055': 1,
#   '106': 3,
#   '106.5': 1,
#   '107.25': 1,
#   '107.41': 1,
#   '108': 1,
#   '109': 4,
#   '11': 99,
#   '11,000': 6,
#   '11,300': 1,
#   '11,500': 1,
#   '11-day': 2,
#   '11-year-old': 6,
#   '11.6': 1,
#   '11.8': 2,
#   '11.9': 1,
#   '110': 11,
#   '111': 3,
#   '112': 3,
#   '113': 4,
#   '114': 7,
#   '115': 4,
#   '115.2': 1,
#   '116': 2,
#   '117': 2,
#   '117-ball': 1,
#   '118': 1,
#   '119': 3,
#   '119.48': 1,
#   '11th': 3,
#   '12': 97,
#   '12,000': 12,
#   '12,027': 1,
#   '12,396': 1,
#   '12,500': 1,
#   '12-hour': 3,
#   '12-kilometer-high': 1,
#   '12-minute': 1,
#   '12-nation': 1,
#   '12-percent': 1,
#   '12-point': 1,
#   '12-year': 1,
#   '12-year-old': 5,
#   '12.3': 1,
#   '12.5': 2,
#   '12.97': 1,
#   '120': 20,
#   '120-member': 3,
#   '121.79': 1,
#   '122': 1,
#   '122.73': 1,
#   '122.8': 1,
#   '123': 5,
#   '124': 3,
#   '125': 5,
#   '126': 1,
#   '128': 6,
#   '128-member': 1,
#   '129': 3,
#   '13': 82,
#   '13,000': 9,
#   '13,100': 1,
#   '13,543': 1,
#   '13-member': 1,
#   '13-point': 1,
#   '13-year': 1,
#   '13-year-old': 6,
#   '13.5': 1,
#   '13.625': 1,
#   '13.65': 2,
#   '13.73': 1,
#   '130': 17,
#   '130.6': 1,
#   '131': 1,
#   '131-5': 1,
#   '132': 4,
#   '132-seat': 1,
#   '133': 2,
#   '134': 1,
#   '135': 6,
#   '136': 2,
#   '137': 2,
#   '139': 2,
#   '13th': 2,
#   '14': 64,
#   '14,000': 10,
#   '14-hour': 1,
#   '14-kilometer-long': 1,
#   '14-month': 1,
#   '14-thousand': 1,
#   '14-year-old': 2,
#   '14.2': 1,
#   '14.5': 2,
#   '14.7': 1,
#   '14.75': 1,
#   '140': 18,
#   '140-kilometers': 1,
#   '141': 1,
#   '141.9': 1,
#   '142': 3,
#   '144': 3,
#   '145': 3,
#   '145.85': 1,
#   '146': 1,
#   '147': 4,
#   '148': 7,
#   '148.9': 1,
#   '149': 1,
#   '149.9': 1,
#   '1493': 1,
#   '14th-century': 1,
#   '15': 132,
#   '15,000': 13,
#   '15,000-ton': 1,
#   '15-20': 1,
#   '15-Feb': 1,
#   '15-kilometer': 2,
#   '15-member': 6,
#   '15-month': 1,
#   '15-nation': 1,
#   '15-year': 4,
#   '15-year-old': 9,
#   '15.1': 1,
#   '15.5': 2,
#   '150': 42,
#   '150-member': 1,
#   '1500': 2,
#   '151': 1,
#   '153.3': 1,
#   '154': 1,
#   '154th': 1,
#   '155': 3,
#   '156': 1,
#   '157': 1,
#   '158': 1,
#   '159': 2,
#   '15th': 1,
#   '16': 57,
#   '16,000': 3,
#   '16-goal': 1,
#   '16-team': 1,
#   '16-year': 3,
#   '16-year-old': 3,
#   '16.125': 1,
#   '16.3': 1,
#   '16.7': 2,
#   '16.8': 3,
#   '160': 14,
#   '1600': 1,
#   '161-seat': 1,
#   '162': 2,
#   '162-page': 1,
#   '163': 2,
#   '163-seat': 1,
#   '1644': 1,
#   '165': 3,
#   '166': 4,
#   '167': 2,
#   '167-seat': 1,
#   '168': 1,
#   '169': 2,
#   '169.9': 1,
#   '16th': 1,
#   '17': 74,
#   '17,000': 9,
#   '17,765': 1,
#   '17-Jan': 1,
#   '17-member': 1,
#   '17-meters': 1,
#   '17-month': 2,
#   '17-year': 6,
#   '17-year-old': 2,
#   '17.2': 1,
#   '17.3': 2,
#   '17.6': 1,
#   '17.9': 1,
#   '170': 13,
#   '170-meter': 1,
#   '171': 2,
#   '173': 2,
#   '174': 1,
#   '175': 2,
#   '175-run': 1,
#   '1750': 1,
#   '176': 1,
#   '177': 1,
#   '178': 1,
#   '179-run': 1,
#   '17th': 2,
#   '17th-century': 1,
#   '18': 62,
#   '18,000': 3,
#   '18,000-strong': 1,
#   '18-a-share': 1,
#   '18-million': 1,
#   '18-month': 3,
#   '18-year': 1,
#   '18-year-old': 3,
#   '18-years-old': 1,
#   '18.46.09': 1,
#   '18.5': 1,
#   '18.7': 1,
#   '180': 8,
#   '181': 1,
#   '184': 3,
#   '185': 4,
#   '185-million': 1,
#   '1861': 1,
#   '188': 1,
#   '19': 43,
#   '19,000': 1,
#   '19-nation': 1,
#   '19-year-old': 4,
#   '19.7': 1,
#   '190': 2,
#   '191': 5,
#   '192': 2,
#   '193': 2,
#   '1939': 1,
#   '197-page': 1,
#   '1975-to-1990': 1,
#   '2': 47,
#   '2,00,000': 46,
#   '2,000': 42,
#   '2,000-years-old': 1,
#   '2,10,000': 2,
#   '2,100': 1,
#   '2,11,000': 2,
#   '2,17,000': 1,
#   '2,20,000': 1,
#   '2,200': 7,
#   '2,200-kilometer': 1,
#   '2,25,000': 1,
#   '2,30,000': 1,
#   '2,300': 2,
#   '2,38,000': 1,
#   '2,400': 2,
#   '2,400-kilometer': 1,
#   '2,46,000': 1,
#   '2,47,000': 1,
#   '2,50,000': 3,
#   '2,500': 8,
#   '2,55,000': 1,
#   '2,600': 2,
#   '2,633-meter': 1,
#   '2,68,000': 1,
#   '2,698': 1,
#   '2,700': 3,
#   '2,720': 1,
#   '2,80,000': 1,
#   '2,800': 3,
#   '2,900': 1,
#   '2-0': 4,
#   '2.1': 4,
#   '2.11.37': 1,
#   '2.2': 4,
#   '2.29': 1,
#   '2.3': 7,
#   '2.3-million-strong': 1,
#   '2.35': 1,
#   '2.38.46': 1,
#   '2.4': 4,
#   '2.5': 19,
#   '2.5-trillion': 1,
#   '2.5-year': 1,
#   '2.6': 4,
#   '2.7': 10,
#   '2.7-million': 1,
#   '2.75': 1,
#   '2.8': 3,
#   '2.9': 3,
#   '2.98': 1,
#   '20': 160,
#   '20,00,000': 1,
#   '20,000': 21,
#   '20-25': 1,
#   '20-meter': 1,
#   '20-month': 1,
#   '20-percent': 1,
#   '20-ton': 2,
#   '20-year': 4,
#   '20-year-old': 7,
#   '20-year-olds': 1,
#   '200': 91,
#   '200-kilometer': 1,
#   '200-meter': 2,
#   '200-mile': 1,
#   '2002': 5,
#   '2004': 4,
#   '2005': 1,
#   '2006': 6,
#   '2007': 1,
#   '2008': 4,
#   '201': 1,
#   '2010': 3,
#   '2012': 3,
#   '2014': 1,
#   '202': 8,
#   '202.7': 1,
#   '203': 2,
#   '203-4': 1,
#   '203.1': 1,
#   '206': 1,
#   '20s': 1,
#   '20th': 1,
#   '21': 32,
#   '21,000': 4,
#   '21-member': 2,
#   '21-month-old': 1,
#   '21-year': 2,
#   '21-year-old': 4,
#   '210': 1,
#   '212-to-206': 1,
#   '215': 1,
#   '216': 1,
#   '217': 1,
#   '218': 1,
#   '22': 32,
#   '22,000': 3,
#   '22-kilometer': 1,
#   '22-month': 1,
#   '22-month-old': 1,
#   '22-nation': 1,
#   '22-year': 2,
#   '22-year-old': 4,
#   '22.4': 1,
#   '220': 10,
#   '220-kilogram': 1,
#   '221': 1,
#   '223': 1,
#   '224': 2,
#   '225': 2,
#   '225-kilometer-long': 1,
#   '225-member': 2,
#   '227': 2,
#   '228': 1,
#   '23': 33,
#   '23,000': 3,
#   '23-member': 1,
#   '23-year-old': 6,
#   '23.5': 2,
#   '23.7': 1,
#   '230': 4,
#   '233': 1,
#   '236': 1,
#   '23rd': 2,
#   '24': 30,
#   '24,000': 1,
#   '24-hour': 3,
#   '24-meter': 2,
#   '24-year-old': 6,
#   '24.5': 1,
#   '240': 7,
#   '241-2661': 1,
#   '243': 1,
#   '246': 1,
#   '248': 2,
#   '249-seat': 1,
#   '25': 98,
#   '25,000': 8,
#   '25-member': 2,
#   '25-meter': 1,
#   '25-million': 1,
#   '25-nation': 1,
#   '25-point': 1,
#   '25-year': 4,
#   '25-year-old': 7,
#   '25-years-old': 1,
#   '250': 19,
#   '254': 3,
#   '255': 1,
#   '256': 1,
#   '257': 2,
#   '258': 3,
#   '259': 1,
#   '26': 31,
#   '26,000': 5,
#   '26,000-member': 1,
#   '26,500': 1,
#   '26,956': 1,
#   '26-member': 1,
#   '26-year': 3,
#   '26-year-old': 3,
#   '260': 4,
#   '261': 1,
#   '264': 1,
#   '265': 2,
#   '266': 1,
#   '269': 1,
#   '27': 33,
#   '27,000': 1,
#   '27-member': 1,
#   '27-year': 2,
#   '27-year-long': 1,
#   '27-year-old': 3,
#   '27.5': 2,
#   '270': 5,
#   '274': 1,
#   '275': 5,
#   '275-member': 5,
#   '275-members': 1,
#   '275-seat': 3,
#   '277': 1,
#   '279-a-ton': 1,
#   '27th': 1,
#   '28': 21,
#   '28,000': 1,
#   '28-member': 1,
#   '28-year-old': 7,
#   '28.25': 1,
#   '280': 3,
#   '281-4': 1,
#   '286': 1,
#   '29': 16,
#   '29,000': 3,
#   '29-member': 1,
#   '29-year-old': 4,
#   '290': 2,
#   '2900': 1,
#   '292': 1,
#   '295': 1,
#   '297-for': 1,
#   '299': 1,
#   '3': 27,
#   '3,00,000': 19,
#   '3,000': 34,
#   '3,04,569': 1,
#   '3,17,000': 1,
#   '3,200-strong': 1,
#   '3,25,000': 1,
#   '3,268': 1,
#   '3,30,000': 3,
#   '3,300': 1,
#   '3,348': 1,
#   '3,400': 1,
#   '3,400-meter-high': 1,
#   '3,50,000': 2,
#   '3,500': 11,
#   '3,587-kilogram': 1,
#   '3,600': 2,
#   '3,65,000': 1,
#   '3,70,000': 1,
#   '3,700': 2,
#   '3,72,000': 1,
#   '3,937': 2,
#   '3-0': 1,
#   '3-billion': 1,
#   '3-point': 1,
#   '3.1': 2,
#   '3.2': 2,
#   '3.29': 1,
#   '3.3': 4,
#   '3.4': 4,
#   '3.5': 6,
#   '3.55': 1,
#   '3.6': 8,
#   '3.7': 4,
#   '3.8': 6,
#   '3.9': 2,
#   '3.913': 1,
#   '30': 108,
#   '30,000': 32,
#   '30-day': 1,
#   '30-kilometer': 1,
#   '30-meter': 1,
#   '30-thousand': 1,
#   '30-year': 2,
#   '30-year-long': 1,
#   '30-year-old': 7,
#   '300': 50,
#   '300-kilometer': 1,
#   '300-km': 1,
#   '300-member': 1,
#   '308-to-106': 1,
#   '30s': 1,
#   '31': 16,
#   '31,000': 2,
#   '31-member': 1,
#   '31-year-old': 11,
#   '31.4': 1,
#   '31.7': 1,
#   '311': 1,
#   '315-member': 1,
#   '31st': 1,
#   '32': 30,
#   '32,000': 4,
#   '32-million-barrel-a-day': 1,
#   '32-year-old': 4,
#   '32.7': 1,
#   '321': 1,
#   '323': 1,
#   '324': 1,
#   '325': 2,
#   '32nd': 1,
#   '33': 15,
#   '33,000': 1,
#   '33.5': 1,
#   '330': 7,
#   '331': 1,
#   '332': 2,
#   '335': 1,
#   '336': 2,
#   '337': 1,
#   '337-9': 1,
#   '34': 22,
#   '34-17': 1,
#   '34-day': 2,
#   '34-member': 1,
#   '34-nation': 1,
#   '34-year-old': 2,
#   '34.5': 2,
#   '340': 1,
#   '346': 1,
#   '35': 28,
#   '35-member': 3,
#   '35-nation': 3,
#   '35-year': 1,
#   '35.2': 1,
#   '350': 10,
#   '350-58': 1,
#   '352': 1,
#   '352-3': 1,
#   '352.9': 1,
#   '356.6': 1,
#   '357': 1,
#   '36': 25,
#   '36-36': 1,
#   '36-year-old': 5,
#   '36.8': 1,
#   '360': 3,
#   '3600': 1,
#   '361': 1,
#   '362.5': 1,
#   '365-5': 1,
#   '367': 1,
#   '37': 13,
#   '37,000': 1,
#   '37-a-share': 1,
#   '37-degree': 1,
#   '37-year-old': 1,
#   '37.5': 1,
#   '370': 4,
#   '3700': 1,
#   '373': 3,
#   '375': 3,
#   '376-7': 1,
#   '377': 1,
#   '38': 14,
#   '38,000': 1,
#   '38-year': 1,
#   '38-year-old': 3,
#   '38.5': 1,
#   '38.68': 1,
#   '38.7': 1,
#   '38.875': 1,
#   '380': 2,
#   '384': 1,
#   '386': 1,
#   '387.8': 1,
#   '388': 1,
#   '39': 11,
#   '39,000': 1,
#   '39-29': 1,
#   '39-year-old': 2,
#   '392': 1,
#   '3D': 2,
#   '4': 25,
#   '4,00,000': 10,
#   '4,000': 21,
#   '4,000-year-old': 1,
#   '4,100-seat': 1,
#   '4,123': 1,
#   '4,20,000': 1,
#   '4,200': 1,
#   '4,27,000': 1,
#   '4,38,000': 1,
#   '4,410-kilogram': 1,
#   '4,50,000': 1,
#   '4,500': 4,
#   '4,56,000': 1,
#   '4,800': 1,
#   '4,867': 1,
#   '4-0': 4,
#   '4.1': 1,
#   '4.2': 2,
#   '4.25': 1,
#   '4.3': 1,
#   '4.4': 2,
#   '4.5': 8,
#   '4.55': 1,
#   '4.6': 3,
#   '4.7': 4,
#   '4.8': 3,
#   '4.9': 1,
#   '40': 115,
#   '40,00,000': 1,
#   '40,000': 8,
#   '40-car': 1,
#   '40-day': 1,
#   '40-member': 1,
#   '40-million': 1,
#   '40-year': 3,
#   '40-year-old': 5,
#   '40.3': 1,
#   '400': 29,
#   '404': 1,
#   '407': 1,
#   '41': 16,
#   '41,000': 1,
#   '41-9': 1,
#   '41-year-old': 2,
#   '41.6': 1,
#   '415': 1,
#   '417': 1,
#   '42': 15,
#   '42,000': 1,
#   '42-year-old': 2,
#   '42.1': 1,
#   '420': 1,
#   '422.5': 1,
#   '423': 1,
#   '423-1': 1,
#   '425': 1,
#   '429': 2,
#   '43': 11,
#   '43,000': 1,
#   '430': 4,
#   '439': 1,
#   '43nd': 1,
#   '43rd': 1,
#   '44': 8,
#   '44,000': 1,
#   '44-yard': 1,
#   '44-year-old': 2,
#   '442': 1,
#   '444': 2,
#   '447': 1,
#   '44th': 1,
#   '45': 20,
#   '45,000': 3,
#   '45,000-person': 1,
#   '45-day': 1,
#   '45-thousand': 1,
#   '45-year-old': 2,
#   '45.2': 1,
#   '45.75': 1,
#   '450': 1,
#   '450-member': 2,
#   '450-seat': 1,
#   '452': 1,
#   '453': 2,
#   '454': 1,
#   '46': 11,
#   '46,000': 2,
#   '46-member': 2,
#   '46-nation': 1,
#   '46-year-old': 2,
#   '46.3': 1,
#   '461': 1,
#   '47': 11,
#   '47,000': 1,
#   '472': 1,
#   '476': 1,
#   '48': 9,
#   '48,000': 2,
#   '48-year-old': 1,
#   '480': 1,
#   '481': 1,
#   '481-': 1,
#   '482': 1,
#   '485': 1,
#   '48th': 1,
#   '49': 7,
#   '49-year': 1,
#   '49-year-old': 3,
#   '49.5': 1,
#   '49.7': 2,
#   '49.8': 1,
#   '492': 1,
#   '4x5-kilometer': 1,
#   '5': 22,
#   '5,00,000': 16,
#   '5,000': 25,
#   '5,19,000': 1,
#   '5,300': 1,
#   '5,49,000': 1,
#   '5,50,000': 1,
#   '5,500-member': 1,
#   '5,52,300': 1,
#   '5,588': 1,
#   '5-member': 1,
#   '5.1': 3,
#   '5.1-magnitude': 1,
#   '5.2': 1,
#   '5.3': 8,
#   '5.4': 2,
#   '5.5': 3,
#   '5.5-hour': 1,
#   '5.63': 1,
#   '5.7': 6,
#   '5.7-kilometer': 1,
#   '5.8': 4,
#   '5.9': 2,
#   '50': 119,
#   '50,000': 13,
#   '50-1': 1,
#   '50-meter': 1,
#   '50-year-old': 2,
#   '50.1': 1,
#   '50.65': 1,
#   '50.9': 2,
#   '500': 47,
#   '500-meter': 1,
#   '500-meters': 1,
#   '500-million': 1,
#   '5000': 1,
#   '51': 12,
#   '51,000': 1,
#   '51-to-44': 1,
#   '51-year-old': 3,
#   '51.4': 1,
#   '51.8': 1,
#   '515': 1,
#   '516': 1,
#   '518': 1,
#   '52': 15,
#   '52-week': 1,
#   '52-year-old': 4,
#   '52.1': 1,
#   '520': 1,
#   '522': 1,
#   '53': 7,
#   '53-country': 1,
#   '53-minute': 1,
#   '53-nation': 2,
#   '53.88': 1,
#   '530': 2,
#   '538': 1,
#   '54': 7,
#   '54,000': 2,
#   '54-page': 1,
#   '54.15': 1,
#   '54.95': 1,
#   '540': 1,
#   '541': 1,
#   '543-member': 1,
#   '545': 1,
#   '55': 22,
#   '55,000': 3,
#   '55-member': 2,
#   '55-nation': 1,
#   '55-to-45': 1,
#   '55-year-old': 2,
#   '55.65': 1,
#   '550': 4,
#   '551': 1,
#   '557': 1,
#   '56': 11,
#   '56-year-old': 1,
#   '561': 1,
#   '567': 1,
#   '57': 11,
#   '57,000': 1,
#   '57-member': 2,
#   '57-year-old': 1,
#   '57.25': 1,
#   '57.5': 1,
#   '57.6': 1,
#   '57.7': 1,
#   '575': 1,
#   '58': 9,
#   '58-to-42': 1,
#   '58-year-old': 4,
#   '58.28': 2,
#   '58.8': 1,
#   '580': 2,
#   '581': 1,
#   '589': 1,
#   '59': 14,
#   '59-year-old': 1,
#   '59.4': 1,
#   '59.9': 1,
#   '590': 1,
#   '592': 1,
#   '598-seat': 1,
#   '59th': 1,
#   '5\xa0storm': 1,
#   '6': 23,
#   '6,00,000': 6,
#   '6,000': 14,
#   ...}}

# %%
count_init_tags = dict(train_data.groupby('Sentence').first().Tag.value_counts())
display(count_init_tags)
# Out:
# {'O': 26999,
#  'B-geo': 1434,
#  'B-per': 1059,
#  'B-org': 982,
#  'B-gpe': 803,
#  'B-tim': 553,
#  'I-per': 410,
#  'I-org': 391,
#  'I-geo': 188,
#  'I-tim': 167,
#  'B-art': 9,
#  'B-eve': 8,
#  'I-art': 8,
#  'B-nat': 6,
#  'I-eve': 5,
#  'I-gpe': 4,
#  'I-nat': 1}

# %%
count_tags_to_next_tags = np.zeros((len(tags), len(tags)),dtype=int)
print(count_tags_to_next_tags.shape)
# Out:
# (17, 17)

# %%
train_data['Sentence'][:5]
# Out:
# 24    Sentence: 31683
# 25     Sentence: 8392
# 26    Sentence: 28070
# 27    Sentence: 40293
# 28    Sentence: 44552
# Name: Sentence, dtype: object

# %%
sentences = list(train_data.Sentence)
print(sentences[:5])
# Out:
# ['Sentence: 31683', 'Sentence: 8392', 'Sentence: 28070', 'Sentence: 40293', 'Sentence: 44552']

# %%
pos = list(train_data.Tag)
print(pos[:10])
# Out:
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'O']

# %%
for i in range(len(sentences)):
    if (i>0) and (sentences[i]==sentences[i-1]):
        prevtagid = tag2id[pos[i - 1]]
        nexttagid = tag2id[pos[i]]
        count_tags_to_next_tags[prevtagid][nexttagid] += 1

# %%
print(count_tags_to_next_tags[0])
# Out:
# [    0 19648  4349     0     0     0   102     0    36     0     1     0
#    507     0    74     0     0]

# %%
mystartprob = np.zeros((len(tags),))
mytransmat = np.zeros((len(tags), len(tags)))
myemissionprob = np.zeros((len(tags), len(words)))
num_sentences = sum(count_init_tags.values())
sum_tags_to_next_tags = np.sum(count_tags_to_next_tags, axis=1)
for tag, tagid in tag2id.items():
    floatCountTag = float(count_tags.get(tag, 0))
    mystartprob[tagid] = count_init_tags.get(tag, 0) / num_sentences
    for word, wordid in word2id.items():
        myemissionprob[tagid][wordid]= count_tags_to_words.get(tag, {}).get(word, 0) / floatCountTag
    for tag2, tagid2 in tag2id.items():
        mytransmat[tagid][tagid2]= count_tags_to_next_tags[tagid][tagid2] / sum_tags_to_next_tags[tagid]

# %%
print(mystartprob.shape)
print(mytransmat.shape)
print(myemissionprob.shape)
# Out:
# (17,)
# (17, 17)
# (17, 29219)

# %%
model = hmm.MultinomialHMM(n_components=len(tags), algorithm='viterbi', random_state=42)
model.startprob_ = mystartprob
model.transmat_ = mytransmat
model.emissionprob_ = myemissionprob
# Out:
# MultinomialHMM has undergone major changes. The previous version was implementing a CategoricalHMM (a special case of MultinomialHMM). This new implementation follows the standard definition for a Multinomial distribution (e.g. as in https://en.wikipedia.org/wiki/Multinomial_distribution). See these issues for details:
# https://github.com/hmmlearn/hmmlearn/issues/335
# https://github.com/hmmlearn/hmmlearn/issues/340

# %%
test_data.loc[~test_data['Word'].isin(words), 'Word'] = 'UNKNOWN'
# Out:
# C:\Temp\ipykernel_12204\3195844866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.loc[~test_data['Word'].isin(words), 'Word'] = 'UNKNOWN'

# %%
word_test = list(test_data.Word)
samples = []
for i, val in enumerate(word_test):
    samples.append([word2id[val]])

# %%
lengths = []
count = 0
sentences = list(test_data.Sentence)
for i in range(len(sentences)) :
    if (i > 0) and (sentences[i] == sentences[i - 1]):
        count += 1
    elif i > 0:
        lengths.append(count)
        count = 1
    else:
        count = 1

# %%
len(lengths)
# Out:
# 14387

# %%
ner_predict = model.predict(samples, lengths)
